# %%
import sweetviz as sv

# %%
import pandas as pd 
import pytz
import numpy as np
import seaborn as sns

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from torchtext.data.utils import get_tokenizer

import matplotlib.pyplot as plt

import torch
from torch import nn 
import torch.nn.functional as F
from torch import utils

torch.manual_seed(0)
np.random.seed(0)

import warnings
warnings.filterwarnings("ignore")

# %%
train=pd.read_csv('https://raw.githubusercontent.com/zerickzhan/Group-20/main/review_train.csv')
challenge=pd.read_csv('https://raw.githubusercontent.com/zerickzhan/Group-20/main/review_challenge.csv')

# %%
train
# Out:
#                 review_id        user_name airline_sentiment  \
# 0      570306133677760513          cairdin           neutral
# 1      570301130888122368         jnardino          positive
# 2      570301083672813571       yvonnalynn           neutral
# 3      570301031407624196         jnardino          negative
# 4      570300817074462722         jnardino          negative
# ...                   ...              ...               ...
# 13757  569587686496825344  KristenReenders          positive
# 13758  569587371693355008         itsropes          negative
# 13759  569587242672398336         sanyabun           neutral
# 13760  569587188687634433       SraJackson          negative
# 13761  569587140490866689        daviddtwu           neutral
#
#        sentiment_confidence         negative_reason  \
# 0                    1.0000                     NaN
# 1                    0.3486                     NaN
# 2                    0.6837                     NaN
# 3                    1.0000              Bad Flight
# 4                    1.0000              Can't Tell
# ...                     ...                     ...
# 13757                0.3487                     NaN
# 13758                1.0000  Customer Service Issue
# 13759                1.0000                     NaN
# 13760                1.0000  Customer Service Issue
# 13761                0.6771                     NaN
#
#        negative_reason_confidence airline_name  \
# 0                             NaN     EgyptAir
# 1                          0.0000     EgyptAir
# 2                             NaN     EgyptAir
# 3                          0.7033     EgyptAir
# 4                          1.0000     EgyptAir
# ...                           ...          ...
# 13757                      0.0000       Qantas
# 13758                      1.0000       Qantas
# 13759                         NaN       Qantas
# 13760                      0.6659       Qantas
# 13761                      0.0000       Qantas
#
#                                              review_text  thumbup_count  \
# 0                                             What said.              0
# 1      plus you've added commercials to the experienc...              0
# 2      I didn't today... Must mean I need to take ano...              0
# 3      it's really aggressive to blast obnoxious "ent...              0
# 4               and it's a really big bad thing about it              0
# ...                                                  ...            ...
# 13757  thank you we got on a different flight to Chic...              0
# 13758  leaving over minutes Late Flight. No warnings ...              0
# 13759      Please bring American Airlines to #BlackBerry              0
# 13760  you have my money, you change my flight, and d...              0
# 13761  we have ppl so we need know how many seats are...              0
#
#       review_coordinates review_timestamp    review_city  \
# 0                    NaN  24/2/2015 11:35            NaN
# 1                    NaN  24/2/2015 11:15            NaN
# 2                    NaN  24/2/2015 11:15      Lets Play
# 3                    NaN  24/2/2015 11:15            NaN
# 4                    NaN  24/2/2015 11:14            NaN
# ...                  ...              ...            ...
# 13757                NaN  22/2/2015 12:01            NaN
# 13758                NaN  22/2/2015 11:59          Texas
# 13759                NaN  22/2/2015 11:59  Nigeria,lagos
# 13760                NaN  22/2/2015 11:59     New Jersey
# 13761                NaN  22/2/2015 11:58     dallas, TX
#
#                     user_timezone
# 0      Eastern Time (US & Canada)
# 1      Pacific Time (US & Canada)
# 2      Central Time (US & Canada)
# 3      Pacific Time (US & Canada)
# 4      Pacific Time (US & Canada)
# ...                           ...
# 13757                         NaN
# 13758                         NaN
# 13759                         NaN
# 13760  Eastern Time (US & Canada)
# 13761                         NaN
#
# [13762 rows x 13 columns]

# %%
# Univariate Analysis

# %%
analyze_report = sv.analyze(train)
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
analyze_report.show_html('report.html')
# Out:
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
analyze_reportchallenge = sv.analyze(challenge)
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
analyze_reportchallenge.show_html('challenge.html')
# Out:
# Report challenge.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
train['review_id'].describe()
# Out:
# count    1.376200e+04
# mean     5.692199e+17
# std      7.793554e+14
# min      5.675883e+17
# 25%      5.685594e+17
# 50%      5.694844e+17
# 75%      5.698917e+17
# max      5.703106e+17
# Name: review_id, dtype: float64

# %% [markdown]
# We need to first identify dependent values, independent values , categorical values, and continuous values before we intitial our EDA analysis.

# %%
train[train["review_id"]==570286841737318400]
# Out:
#                 review_id    user_name airline_sentiment  \
# 11230  570286841737318400  djjohnpayne          negative
# 11384  570286841737318400  djjohnpayne          negative
#
#        sentiment_confidence   negative_reason  negative_reason_confidence  \
# 11230                   1.0  Cancelled Flight                      0.6304
# 11384                   1.0  Cancelled Flight                      1.0000
#
#       airline_name                                    review_text  \
# 11230       Qantas  you guys are killing me. http://t.co/iPGeIcSm
# 11384       Qantas  you guys are killing me. http://t.co/iPGeIcSm
#
#        thumbup_count review_coordinates review_timestamp    review_city  \
# 11230              0         [0.0, 0.0]  24/2/2015 10:19  Las Vegas, NV
# 11384              0         [0.0, 0.0]  24/2/2015 10:19  Las Vegas, NV
#
#                     user_timezone
# 11230  Pacific Time (US & Canada)
# 11384  Pacific Time (US & Canada)

# %%
train[train["review_id"]==570267562623152128]
# Out:
#                 review_id      user_name airline_sentiment  \
# 11298  570267562623152128  alinaxkristin          negative
# 11453  570267562623152128  alinaxkristin          negative
#
#        sentiment_confidence              negative_reason  \
# 11298                   1.0  Flight Attendant Complaints
# 11453                   1.0  Flight Attendant Complaints
#
#        negative_reason_confidence airline_name  \
# 11298                      1.0000       Qantas
# 11453                      0.6688       Qantas
#
#                                              review_text  thumbup_count  \
# 11298  you could train your flight attendants to have...              0
# 11453  you could train your flight attendants to have...              0
#
#       review_coordinates review_timestamp review_city user_timezone
# 11298                NaN   24/2/2015 9:02      Miami          Quito
# 11453                NaN   24/2/2015 9:02      Miami          Quito

# %%
train=train.sort_values(by=['sentiment_confidence'])
train=train.drop_duplicates(subset=['review_id'], keep='last')

# %% [markdown]
# from the above example we can see several values are duplicated with the only difference being the negative_reason_confidence, which made the review_id not an unique key.
# Therefore, we will remove the values with lower sentiment confidence.

# %%
train = train.drop_duplicates(subset='review_id', keep="first")

# %% [markdown]
# Changed sentiment analysis from words into numeric values

# %%
train.describe()
# Out:
#           review_id  sentiment_confidence  negative_reason_confidence  \
# count  1.362000e+04          13620.000000                 9784.000000
# mean   5.692091e+17              0.900895                    0.639702
# std    7.760599e+14              0.162454                    0.330721
# min    5.675883e+17              0.335000                    0.000000
# 25%    5.685521e+17              0.693200                    0.360900
# 50%    5.694595e+17              1.000000                    0.670700
# 75%    5.698832e+17              1.000000                    1.000000
# max    5.703106e+17              1.000000                    1.000000
#
#        thumbup_count
# count   13620.000000
# mean        0.083480
# std         0.766913
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        44.000000

# %%
fig, ax = plt.subplots()
ax.set(title ="Histogram ")
sns.distplot(a=train[["thumbup_count"]], bins=20)
fig, ax = plt.subplots()
ax.set(title ="Histogram of ApplicantIncome")
sns.boxplot(x="thumbup_count", data=train)
# Out:
# <AxesSubplot:title={'center':'Histogram of ApplicantIncome'}, xlabel='thumbup_count'>

# %%
fig, ax = plt.subplots()
ax.set(title ="Histogram ")
sns.distplot(a=train[["sentiment_confidence"]], bins=20)
# Out:
# <AxesSubplot:title={'center':'Histogram '}, ylabel='Density'>

# %%
train
# Out:
#                review_id      user_name airline_sentiment  \
# 930   569972097453137920  cristobalwong           neutral
# 5873  568092537786748928  VegasRenegade           neutral
# 5963  568028183267639297      CourtSnod          positive
# 7436  568993773277069312  KoolieAshSays           neutral
# 2254  569227372223811584   zachkpearson          positive
# ...                  ...            ...               ...
# 5281  568853498726449152     djknuckles           neutral
# 5282  568853440794730496      woman4lif           neutral
# 5283  568852204750135296      woman4lif           neutral
# 5274  568858194447085568      LRC110979          negative
# 6880  569671231001092096    malbeckford          negative
#
#       sentiment_confidence         negative_reason  \
# 930                 0.3350                     NaN
# 5873                0.3353                     NaN
# 5963                0.3356                     NaN
# 7436                0.3363                     NaN
# 2254                0.3366                     NaN
# ...                    ...                     ...
# 5281                1.0000                     NaN
# 5282                1.0000                     NaN
# 5283                1.0000                     NaN
# 5274                1.0000  Customer Service Issue
# 6880                1.0000  Customer Service Issue
#
#       negative_reason_confidence        airline_name  \
# 930                       0.0000            Emirates
# 5873                      0.0000           Lufthansa
# 5963                      0.0000           Lufthansa
# 7436                      0.0000  Singapore Airlines
# 2254                      0.0000            Emirates
# ...                          ...                 ...
# 5281                         NaN           Lufthansa
# 5282                         NaN           Lufthansa
# 5283                         NaN           Lufthansa
# 5274                      0.6564           Lufthansa
# 6880                      0.6699  Singapore Airlines
#
#                                             review_text  thumbup_count  \
# 930   Thank you, ^JH, appreciate the prompt response...              0
# 5873                    All Flights lead to VEGAS BABY!              1
# 5963                             de-icing is important!              0
# 7436                           oh. Makes sense. My bad.              0
# 2254       . Thanks. Hopefully this is easily resolved.              0
# ...                                                 ...            ...
# 5281  hello I was talking with but it says you moved...              0
# 5282                            I am following you now.              0
# 5283  I can go. I want to badly!!!! I don't know how...              0
# 5274  yes but not with out an attitude and nasty com...              0
# 6880  "Considering?" #Accessibility is an absolute M...              1
#
#                review_coordinates review_timestamp  \
# 930                           NaN  23/2/2015 13:28
# 5873                          NaN   18/2/2015 8:59
# 5963                          NaN   18/2/2015 4:44
# 7436    [40.88529232, -73.856635]  20/2/2015 20:41
# 2254                          NaN  21/2/2015 12:09
# ...                           ...              ...
# 5281                          NaN  20/2/2015 11:23
# 5282                          NaN  20/2/2015 11:23
# 5283                          NaN  20/2/2015 11:18
# 5274  [41.93001697, -72.68496357]  20/2/2015 11:42
# 6880                          NaN  22/2/2015 17:33
#
#                      review_city                user_timezone
# 930       San Francisco Bay Area                          NaN
# 5873        The Wild Blue Yonder       Atlantic Time (Canada)
# 5963          Tennessee Original   Central Time (US & Canada)
# 7436  ÜT: 17.9889591,-76.7712636   Pacific Time (US & Canada)
# 2254            Portland, Oregon   Pacific Time (US & Canada)
# ...                          ...                          ...
# 5281                   WORLDWIDE   Pacific Time (US & Canada)
# 5282                 Northern UT  Mountain Time (US & Canada)
# 5283                 Northern UT  Mountain Time (US & Canada)
# 5274         Rochester Hills, MI   Eastern Time (US & Canada)
# 6880                         NaN                          NaN
#
# [13620 rows x 13 columns]

# %%
train['review'] = train.apply(lambda row: row['negative_reason'] if not pd.isna(row['negative_reason']) and row['negative_reason'] != '' else row['airline_sentiment'], axis=1)

# %%
pd.crosstab(train['airline_name'], train['review'])
# Out:
# review                1    2  Bad Flight  Can't Tell  Cancelled Flight  \
# airline_name
# EgyptAir            155  142          18          21                17
# Emirates            660  465         208         351               166
# Lufthansa           623  537          82         152               149
# Qantas              404  293          78         176               218
# Qatar Airways       361  256          97         228               175
# Singapore Airlines  677  508          59         172                49
#
# review              Customer Service Issue  Damaged Luggage  \
# airline_name
# EgyptAir                                57                4
# Emirates                               637               20
# Lufthansa                              367               13
# Qantas                                 693               10
# Qatar Airways                          773               10
# Singapore Airlines                     181                8
#
# review              Flight Attendant Complaints  Flight Booking Problems  \
# airline_name
# EgyptAir                                      5                       27
# Emirates                                    156                      132
# Lufthansa                                    37                       60
# Qantas                                       77                      117
# Qatar Airways                               118                      116
# Singapore Airlines                           58                       41
#
# review              Late Flight  Lost Luggage  longlines
# airline_name
# EgyptAir                     16             3          1
# Emirates                    492           261         46
# Lufthansa                   146            87         27
# Qantas                      223           137         31
# Qatar Airways               425           143         47
# Singapore Airlines          255            52         14

# %% [markdown]
# # Bivariate Analysis

# %%
filtered_data_number = train[train['user_name'].str.contains(r'\d', regex=True, na=False)]

# %%
train[train['review_city']=='Does it really matter']
# Out:
#                review_id     user_name  airline_sentiment  \
# 8810  569959415433965569  ElmiraBudMan                  0
# 9127  569694350831161344  ElmiraBudMan                  0
# 8771  569971542538346496  ElmiraBudMan                  0
# 8777  569970626057801728  ElmiraBudMan                  1
# 9138  569686602940858368  ElmiraBudMan                  0
# 9150  569682545375354880  ElmiraBudMan                  0
# 9199  569660306298945537  ElmiraBudMan                  0
# 9198  569661113593425920  ElmiraBudMan                  0
# 9202  569659137581326336  ElmiraBudMan                  0
# 9204  569658553381883905  ElmiraBudMan                  0
# 9205  569658168097292288  ElmiraBudMan                  0
# 8795  569967469135142914  ElmiraBudMan                  0
# 8794  569967808446009345  ElmiraBudMan                  0
# 8791  569968609440563201  ElmiraBudMan                  0
# 8805  569960904852312064  ElmiraBudMan                  0
# 8809  569959975566467072  ElmiraBudMan                  0
# 8745  569985288992264192  ElmiraBudMan                  0
# 8783  569969714245431296  ElmiraBudMan                  0
# 8769  569972250385862656  ElmiraBudMan                  0
#
#       sentiment_confidence              negative_reason  \
# 8810                0.6702  Flight Attendant Complaints
# 9127                0.6718       Customer Service Issue
# 8771                0.6902                   Can't Tell
# 8777                0.7010                          NaN
# 9138                1.0000                   Bad Flight
# 9150                1.0000                  Late Flight
# 9199                1.0000                   Can't Tell
# 9198                1.0000                   Bad Flight
# 9202                1.0000  Flight Attendant Complaints
# 9204                1.0000                  Late Flight
# 9205                1.0000                   Can't Tell
# 8795                1.0000                  Late Flight
# 8794                1.0000       Customer Service Issue
# 8791                1.0000             Cancelled Flight
# 8805                1.0000       Customer Service Issue
# 8809                1.0000       Customer Service Issue
# 8745                1.0000       Customer Service Issue
# 8783                1.0000  Flight Attendant Complaints
# 8769                1.0000                 Lost Luggage
#
#       negative_reason_confidence   airline_name  \
# 8810                      0.6702  Qatar Airways
# 9127                      0.6718  Qatar Airways
# 8771                      0.6902  Qatar Airways
# 8777                      0.0000  Qatar Airways
# 9138                      0.6596  Qatar Airways
# 9150                      0.6632  Qatar Airways
# 9199                      1.0000  Qatar Airways
# 9198                      0.3481  Qatar Airways
# 9202                      1.0000  Qatar Airways
# 9204                      0.6775  Qatar Airways
# 9205                      0.6315  Qatar Airways
# 8795                      0.3681  Qatar Airways
# 8794                      0.6805  Qatar Airways
# 8791                      1.0000  Qatar Airways
# 8805                      1.0000  Qatar Airways
# 8809                      1.0000  Qatar Airways
# 8745                      0.3561  Qatar Airways
# 8783                      0.6736  Qatar Airways
# 8769                      0.6723  Qatar Airways
#
#                                             review_text  thumbup_count  \
# 8810  I get some bs from a guy at the door says door...              0
# 9127  always nice when a customer service manager th...              0
# 8771  the exhaustion of traveling n runnin thru the ...              0
# 8777  doesn't take into account the $ it cost rent a...              0
# 9138  why the hell did you overbook a plane when you...              0
# 9150  we don't control your stupidity in not having ...              0
# 9199  this is the reason I avoid and like the plague...              0
# 9198  how can a plane scheduled to come in on time a...              0
# 9202  hire smarter IT people if your systems keep cr...              0
# 9204  what is wrong with you guys and your inability...              1
# 9205  you guys have to be the worst. We are flying i...              0
# 8795  you idiots kept an on time plane on the Tarmac...              0
# 8794  if you actually cared about what you did it wo...              0
# 8791  is okay for u Cancelled Flight change a flight...              0
# 8805  just an FYI I'll be writing registered letters...              0
# 8809  I find it funny that responds but you don't. Y...              0
# 8745  PLANS CHANGED! IS THAT WHAT U CALL NOT BEIN AB...              0
# 8783  we had a friend there telling the gate attenda...              0
# 8769  only happened because u couldn't get us home t...              0
#
#      review_coordinates review_timestamp            review_city user_timezone  \
# 8810                NaN  23/2/2015 12:38  Does it really matter          None
# 9127                NaN  22/2/2015 19:04  Does it really matter          None
# 8771                NaN  23/2/2015 13:26  Does it really matter          None
# 8777                NaN  23/2/2015 13:22  Does it really matter          None
# 9138                NaN  22/2/2015 18:34  Does it really matter          None
# 9150                NaN  22/2/2015 18:17  Does it really matter          None
# 9199                NaN  22/2/2015 16:49  Does it really matter          None
# 9198                NaN  22/2/2015 16:52  Does it really matter          None
# 9202                NaN  22/2/2015 16:44  Does it really matter          None
# 9204                NaN  22/2/2015 16:42  Does it really matter          None
# 9205                NaN  22/2/2015 16:41  Does it really matter          None
# 8795                NaN  23/2/2015 13:10  Does it really matter          None
# 8794                NaN  23/2/2015 13:11  Does it really matter          None
# 8791                NaN  23/2/2015 13:14  Does it really matter          None
# 8805                NaN  23/2/2015 12:44  Does it really matter          None
# 8809                NaN  23/2/2015 12:40  Does it really matter          None
# 8745                NaN  23/2/2015 14:20  Does it really matter          None
# 8783                NaN  23/2/2015 13:19  Does it really matter          None
# 8769                NaN  23/2/2015 13:29  Does it really matter          None
#
#                            review  user_name_count
# 8810  Flight Attendant Complaints               19
# 9127       Customer Service Issue               19
# 8771                   Can't Tell               19
# 8777                            1               19
# 9138                   Bad Flight               19
# 9150                  Late Flight               19
# 9199                   Can't Tell               19
# 9198                   Bad Flight               19
# 9202  Flight Attendant Complaints               19
# 9204                  Late Flight               19
# 9205                   Can't Tell               19
# 8795                  Late Flight               19
# 8794       Customer Service Issue               19
# 8791             Cancelled Flight               19
# 8805       Customer Service Issue               19
# 8809       Customer Service Issue               19
# 8745       Customer Service Issue               19
# 8783  Flight Attendant Complaints               19
# 8769                 Lost Luggage               19

# %%
user_to_city_mapping = train[train['user_timezone'] != ''].groupby('user_name')['user_timezone'].first()

# Fill in the empty review_city values using the mapping
train['user_timezone'] = train.apply(
    lambda row: user_to_city_mapping.get(row['user_name'], row['user_timezone']),
    axis=1
)

# %%
train[train['user_name']=="somekidnamedjon"]
# Out:
#                review_id        user_name  airline_sentiment  \
# 8336  567776348828360707  somekidnamedjon                  2
#
#       sentiment_confidence negative_reason  negative_reason_confidence  \
# 8336                0.6485             NaN                         NaN
#
#             airline_name                                        review_text  \
# 8336  Singapore Airlines  I would love for you to fly my best friend hom...
#
#       thumbup_count review_coordinates review_timestamp review_city  \
# 8336              0                NaN  17/2/2015 12:03        ✈️✈️
#
#                    user_timezone review  user_name_count
# 8336  Eastern Time (US & Canada)      2                1

# %% [markdown]
# we need to identify spams and elimination of data that attribute nothing to the sentimente analysis:<br>
# we found that news and user spams are both included in the database.
# In the mean time we also don't see much values in the timezone. As user time zone does not impact sentiment of their
# Therefore, we decide to not include that column too.
#
# We would also get ride off the he thumb_up data as it contains a 94% zero value.

# %% [markdown]
# creat a column that is a count of occurance of the user name

# %%
train['user_name_count'] = train.groupby('user_name')['user_name'].transform('count')

# %%
user_name_count = train['user_name_count'].value_counts()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(user_name_count, labels=user_name_count.index, autopct='%1.1f%%', startangle=90)
plt.title('User Name Count Distribution')
plt.show()

# %% [markdown]
# I want to see the distribution for airline sentiment where only user name that contained numbers are selected.

# %%
sentiment_counts=filtered_data_number['airline_sentiment'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Airline Sentiment Distribution')
# Out:
# Text(0.5, 1.0, 'Airline Sentiment Distribution')

# %%
user_name_counts = train['user_name'].value_counts()
filtered_df = train[train['user_name'].isin(user_name_counts[user_name_counts<6].index)]

# %%
count_blank = len(train[(train['user_timezone'].isna() | train['user_timezone'].eq('')) & (train['review_city'].isna() | train['review_city'].eq(''))])

print("Number of rows where both 'review_timestamp' and 'review_city' are blank:", count_blank)
# Out:
# Number of rows where both 'review_timestamp' and 'review_city' are blank: 2473

# %%
count_blank2 = len(train[
    (train['user_timezone'].isna() | train['user_timezone'].eq('')) &
    (train['review_city'].isna() | train['review_city'].eq('')) &
    (train['review_coordinates'].isna() | train['review_coordinates'].eq(''))
])

print("Number of rows where 'user_timezone', 'review_city', and 'review_coordinates' are blank:", count_blank)
# Out:
# Number of rows where 'user_timezone', 'review_city', and 'review_coordinates' are blank: 2473

# %%
debug_selection = len(train[(train['negative_reason_confidence'].isna()) & (train['airline_sentiment'] == 'negative')])
print(debug_selection)
# Out:
# 0

# %% [markdown]
# as we can see, the reivew text for sentiments contain things like #Name and thanks. It would be resasonable for us to exclude those from our anlysis as

# %% [markdown]
# From the above EDA extracts we can see: <br>
# 1. The airline sentiment are separated into 3 different kinds with 63% in negative, 21% in neural, and 16% in positive.<br>
# 2. There are 10 negative reasons, and the top 1 accounts for 32% being: Customer service Issue.<br>
# 3. We can see the data is collected from 6 different airline companies, with the top 3 being Emirate (26%), Qatar Airways(20%), and Qantas (19%)<br>
#
# <br>
# The data is suffering from missing data:<br>
#
# 1. 92.24% of review coordinates are missing, we this varible is going to cause collinearity issue with review city and we decide to keep review city. <br>
#
# 2. Contrary to our believe,review city and user time zone do not share all its missing rows. Only 2499 rows are missing for both review city and review time_zone. The inclusion of review coordinate can bring this down to 2418.<br>
#
# 3. The missing values of negative_reason is caused by the airline_sentiment not being negative. we are going to create a new column called reivew and backfill " positive" or "neural" for the missing values.

# %% [markdown]
# Due to the frequent apperance of unformted and incorrect entries, we are unable to use review city and decide to remove that one.
# Due to the huge amount of missing data for the review coordianate. we decide to remove this column too.

# %% [markdown]
# ## Feature Engineering

# %%
# preprocessing data
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder() 
target = le.fit_transform(train['airline_sentiment']) # convert target into integers
train['airline_sentiment'] = target
print(le.classes_) # this shows which index maps to which class
# Out:
# [0 1 2]

# %%
np.random.seed(511365)

index = list(range(train.shape[0])) # an list of indices
np.random.shuffle(index) # shuffle the index in-place

p_val = 0.2
p_test = 0.2
N_test = int(train.shape[0] * p_test)
N_val = int(train.shape[0] * p_val)


# get training, val and test sets
test_data = train.iloc[ index[:N_test] ,:]
val_data = train.iloc[ index[N_test: (N_test+N_val)], :]
train_data = train.iloc[ index[(N_test+N_val):], :]

print(test_data.shape)
print(val_data.shape)
print(train_data.shape)
# Out:
# (2724, 15)
# (2724, 15)
# (8172, 15)

# %%
# define our own torch dataset
# for a torch dataset, we need to define two functions: 
#     __len__: return the length of dataset
#     __getitem__: given a index (integer), return the corresponding sample, both y and X

class SpamDataset(utils.data.Dataset):
    def __init__(self, myData):
        """
        myData should be a dataframe object containing both y (first col) and X (second col)
        """
        super().__init__()
        self.data = myData
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        
        return (self.data.iloc[idx,2], self.data.iloc[idx,7]) # (target, text)

# %%
# now we can build our torch dataset 
train_torch = SpamDataset(train_data)
val_torch = SpamDataset(val_data)
test_torch = SpamDataset(test_data)

# %%
tokenizer = get_tokenizer('basic_english')

# %%
from torchtext.vocab import build_vocab_from_iterator

# ===== Build vocabulary =====
# an unknown token is added for all unknown words outside the documents
# you may specify the min_freq to filter out infrequent words
vocabulary = build_vocab_from_iterator(
    [tokenizer(msg) for msg in train['review_text']],
    specials=["<unk>"],
    min_freq = 3, # filter out all words that appear less than three times
)
# Set to avoid errors with unknown words
vocabulary.set_default_index(vocabulary["<unk>"])

# %%
# define a function that converts a document into tokens (represented by index)
def doc_tokenizer(doc):
    return torch.tensor([vocabulary[token] for token in tokenizer(doc)], dtype=torch.long)

# %%
# define a function that converts a document into tokens in list instead of tensor
def doc_tokenizer2(doc):
    return [vocabulary[token] for token in tokenizer(doc)]

# %%
# ========= Step 2 ==============
# Notice in a corpus, each document can have different size. Thus, we usually pad zeros to the maximum length of document.
# Alternatively, you can concat all documents into a long vector 
# and the starting index of each document is identified in the variable called offsets.

def collate_batch(batch):
    
    target_list, text_list, offsets = [], [], [0] # initalize the first offset to be 0 here
        
    # loop through all samples in batch
    for idx in range(len(batch)):
        
        _label = batch[idx][0]
        _text = batch[idx][1]
        
        target_list.append( _label )
        tokens = doc_tokenizer( _text )
        text_list.append(tokens)
        
        # ====== wrong ======
        #if idx == 0:
        #    offsets.append(0)  # the first document starts from idx 0
        #else:
        #    offsets.append(offsets[-1] + tokens.size(0)) # the next document starts from (offsets[-1] + tokens.size(0))
        # ===================
        
        offsets.append(offsets[-1] + tokens.size(0))
    
    offsets = offsets[:-1] # remove the last entry
    
    # convert to torch tensor
    target_list = torch.tensor(target_list, dtype=torch.int64)
    offsets = torch.tensor(offsets)
    text_list = torch.cat(text_list) # concat into a long vector
    
    return target_list, text_list, offsets

# %%
torch.manual_seed(0)

batchSize = 8
train_loader = utils.data.DataLoader(train_torch, batch_size=batchSize, shuffle=True, collate_fn=collate_batch)
val_loader = utils.data.DataLoader(val_torch, batch_size=batchSize, shuffle=True, collate_fn=collate_batch)
test_loader = utils.data.DataLoader(test_torch, batch_size=batchSize, shuffle=False, collate_fn=collate_batch)

# %%
train_sentiment= list(train_data['airline_sentiment'])
train_review_text= []
for idx in range(len(train_data['review_text'])):
    token=doc_tokenizer2( list(train_data['review_text'])[idx])
    train_review_text.append(token)

# %%
list(train_loader)
# Out:
# [(tensor([0, 0, 0, 0, 0, 0, 0, 1]),
#   tensor([2582,   15, 1984,   30,  706,  132,    0,  873,   17,   29,    4,  968,
#             43,    1,  448,  133,   89,    0,  195, 1022,    0, 2213, 1629,    1,
#            124,   12,  264,  205,   29,  873,  107,    6,  316, 1015,   29,  319,
#              1,   31,  912,   51,    3,   33, 3209,   81,    2,    0,  914,  142,
#            359,   18,  253,    3,    5,   59, 1498,    1,  106,   44,   96,  234,
#             14,   74,   27,  137,    4,   71,    1, 1014, 1002,  105,    9,   14,
#             22, 2426,   17,    0,    4,  222,   56,  200,    1,   18,    5,   28,
#             27,    8,  514,   18,    5,   28,    8,    0, 2445,    0,   13,    8,
#           1392,  202,    1,   16,  421, 3835,  534, 1695,   30,  314,    1,    3,
#              5,   93,  124,   49, 3484,   38,  172,   13,    8,   12,   29,   15,
#              0,    1,  368,   11,   15,  554,  113, 1168,  474,   45,    2,   27,
#            135,  189,   32,   11,    4,  836,  119,   84,  213,   47,    3,  342,
#             11,  720,  180,    0,    7]),
#   tensor([  0,   6,  32,  56,  81,  99, 122, 140])),
#  (tensor([0, 1, 0, 0, 1, 0, 1, 0]),
#   tensor([   0,   51,    5,   28,   57,   29,  157,   11,  261, 3597,    7, 1546,
#            110,   11,  190,   11,  153,    1,    1,    1,   31,  409,    1, 1349,
#           3275,   27, 3335,    1,  466,   18,   16,   45,    8, 2406,    1,    1,
#              1,  239,  266,   80,   14,   45,   95,   44,  186,   23,   15,   80,
#             12,   16,    0,   27,  197,   15,   12,   26,   42,   90,   38, 1994,
#              2, 3122,    0,   14,    3,   80,  234,   30,    4,  114,    1,   47,
#              9,  108, 1059,   11,   32,    7,   24,    9,   50,   21, 1638,   15,
#            202,    7,  341,  192,  200,    1, 1655,  267, 2209,   35,  193,   42,
#            684,   20,  945,    0,  540,   21,  193,  185, 4096,  160, 1086,   10,
#           1712,   38, 3387,   39,   36,    1,    0,  318,   43,    4, 1660,    0,
#              7,    5,   34,    5,  176,  398,    2,   33,   92,  335,   20,    9,
#             92,   34,   24,   13,   32,   71,    5]),
#   tensor([  0,  28,  37,  53,  78,  86, 104, 116])),
#  (tensor([0, 2, 1, 2, 0, 0, 2, 1]),
#   tensor([  15,  514,  175,  157,   13,   12,    1,   51,    2,   47,    7,  118,
#             12,   95,   61,   81,   13,   52,    6,   41,   41,    6,    3,   45,
#            217,    8,  513, 3622,    1,  824,  470,  296,   14,  335,  268,  981,
#            105,    8,   42,  786,   10,   74,  172,    2,  402,   41,    2,  118,
#             86,  250,    6, 1758,   32, 2246,   45,  170,    2, 1378, 2718,    0,
#             32, 1840,   14,   22,  404,   30,  372,    1,  341,   56,  200,   43,
#             32,   39,   36,    1,    0,  118,   10,   41,    1,  981,    1,  652,
#             98,  204,  116,  390,    2, 1923, 1790, 1331,    4,  179,   62,    7]),
#   tensor([ 0, 11, 20, 29, 51, 71, 77, 83])),
#  (tensor([0, 0, 0, 0, 0, 2, 2, 1]),
#   tensor([1778,   35,    3,   26,  570,    2, 1343,    4,  164, 1063, 1236,   92,
#              8,  798, 1292,    7, 3365,    0,    0,  233,   70,   11,   11,  113,
#              1,   26,  721,  113,    1,  480,    1,  743,    3,   24,    5,   19,
#           1463, 1138,  575, 1634,    1,   79,   25,  933, 1826,    1,  162,  265,
#             54,   40,   27,  421,  284,  220,   54,   79,  379,    2, 1399,   83,
#           1885, 3000, 1430,   65,  216,   23,   50,    4,  173,   56,   46,   17,
#            440,    1,  234,   13,   29,    4, 1985, 2911,    2,  398,   14,    0,
#              4,  838,  964,    1,    1,    1,    1, 2397,  429,   11,   15,  159,
#             12,   92,    8, 1466,  573,  291,    6,   73,    9,   63, 3468,  332,
#              3,  152,    2,   17,    4,  720,    3,  644,   78,    2, 1027,   10,
#            681,    7]),
#   tensor([  0,  19,  46,  67,  74, 101, 103, 106])),
#  (tensor([1, 2, 2, 0, 2, 0, 0, 2]),
#   tensor([ 763,    6,   15,  806,  705,   61,    8,  202,  136,  257,   66,   45,
#           2009,   15,  136,  352,   16,    0,    6,   51,   24,    3,   47,    7,
#             41,    6,  486,   91,  480,    8,  348,    1,  541,    2,   33,  497,
#             52,   38,  177, 3281,    1,   35,  182,  134,   29,    9,  108,    6,
#             41,   48,  188,    6,  191,   26,    4,  173,  200,    3,    5,   93,
#            178,   87,  134,    1,  287,   10,  268,   10,   42,  684,   10,  545,
#             20,  678,   10,   14, 1480,   60,   52,   12,    2, 1467,  249,    0,
#             66,    0,  348,    0,    1,    8,  385,  183,   26,   17,  527,  105,
#             21, 4038,    2,   50,   21,   33,    4, 3492,   66,  153,  137,    1,
#              0,    6,    6,   27,  236,   51,  560,  455, 1733,  328,   10,   35,
#            158, 1228,   15,   88,   26,   27,  121,   82,   10,   35,  556,   30,
#           1733,   11,  132,  387, 1201,  455,   80,   41,   11,  248,    1,  179,
#             52,    3,    5,  176,  631,    8,  664,  367, 1271,   11,   15,  367,
#           3904,    1,   23,  504,  814,   10,  197,    7, 3310,    1,  335,   41,
#              1,  315,  597,    2,  194,   81,   13,  203,  129,    1,   87,    8,
#            118,   12,   57,    2,    0,    1]),
#   tensor([  0,  26,  48,  52,  79, 111, 139, 164])),
#  (tensor([0, 0, 1, 0, 0, 0, 0, 0]),
#   tensor([   0,  230,  433,  549,    7,   47,    9,  596,  524,    2,  135,   13,
#              8,    0,    0, 4077,   20, 4062,  309,  230, 3675,  414, 1011,    7,
#             14,    1,   27,    2, 3185,   13,   10,   35,   18,    5,   28,   52,
#              2,  324,   22,   17,   12,  700,    0,    1,   39,   36,    1,    0,
#              0, 1680, 1948,   39,   36,    1,    0,   97,    5,   19,  156,    8,
#              0,  540,    2,   33,   13,   44,  384,   12,   29,  198,    1,   31,
#            104, 1684,    2,    0,   33,  195,  210,   17,  384, 1070,  503,   26,
#            233,  189,  163,   35,   29,    0,    1,  163,   89,   27,  247, 1499,
#              0,    1,    3,   80, 3331,   20,  666,  828,  165,  122,    3, 1136,
#           1352,  161,    7,    3,  223,  301,  241,   15,   12,  216,  304,  403,
#            177,   30,    4,  908,  267, 1103,    7,   39,   36,    1,    0,   68,
#              9, 2223,  167,   17,    8,  621,  333,  157,    9,   79,  244,  166,
#             79,  151,    2, 1599,   22,  322,   10,   35,  531,   27,    7]),
#   tensor([  0,  24,  48,  55,  81, 105, 117, 131])),
#  (tensor([0, 2, 0, 0, 1, 1, 1, 2]),
#   tensor([  32,   16,    4,  173,   56,   46,    3,   25,  178,   87,    1,  275,
#              2, 2057,   35,  154,  310,   13, 1377,    1,  796,    1,  364,   21,
#              1,  290,   14,  384,   81,  140,    6,   39,   36,    1,    0,    9,
#             40,  130,  112,   21,  100,    1,   32,   16,   31,  116,    2,  749,
#           2494,    1,    3,  151,  167,    2,  364,   21,   14,  801,   65,   54,
#             53,  128,   32,  994,    1,   78,    2,  131,   12,   38,   32,  736,
#              2, 1892,    2, 2281,    2,    0, 3169,   17,  960,   10,   78,   50,
#              6,    6, 2509,   15,   12,  165,   16,   59,   24,    3,  226,  703,
#            192,   13, 3647,   29,  908,  267,    7,    9,  496,   40,    4,  222,
#            747,   20,  134,    6]),
#   tensor([  0,  25,  35,  42,  65,  87,  92, 103])),
#  (tensor([0, 0, 2, 0, 0, 0, 0, 1]),
#   tensor([  62,   13,    4,  114,   31,    0,  120,   27, 1411,    8,  677,    2,
#             37, 2389,   17,    4, 2606,   10,  526,  147,    4, 3943,   20,    4,
#             85, 1134,   16,    4,  222,  104,   58,   69,   31,   77,   16,  224,
#            168,  161,    0, 1921, 2838,  174,    3,   25,   25,   49,  112,    2,
#            615,  431,  263,  228,  136,  909,    2,   42,   12,   70,    1,  173,
#             56,   46,  178,    6,   51,   43,    7,    7,    7,    3,  276,  480,
#              4, 2760,  253,   23,   18,   89,  194,  758,    2,   15, 3450,   35,
#             18,   16,   27,  141,    7,   56,   46,   30,  587,   10,  706,   10,
#             14, 1866,   25,   49,  341,    1,   31,   77,  935,  213,  414,  153,
#             40,    1,  414,   16,   13,    8,  416,   29,   31,  722,   66, 1610,
#           1758,   54,    5,   93,  265,   23,   14,  114,    0,   70,   48,   54,
#              5,  115,  452,   30,  336,    1,   31,  420,   20,    8,  271,   11,
#            161,    7]),
#   tensor([  0,   4,  26,  41,  44,  69,  89, 120])),
#  (tensor([2, 0, 0, 0, 0, 0, 0, 2]),
#   tensor([  41,   11,   23,    1,   49, 2720,    8,  116,    2,  128,  435,  753,
#           1180,   38,  382,   10,   14,   43,    9,    5,   93,  312,  189,    6,
#              3,  111,   10,   35,    3,  628,    2,  358,   18, 1192,    1,   27,
#            139,   11,    4,   19,  200, 2351,   11,  167,  183, 3034,   55,  231,
#              8,  686,    1, 1980, 1014,   38,  525,    2,  172,   88,   77,   96,
#              1,   23,    5,   28,  158,  792,    1,  456, 1572,   12,   16,   82,
#              1,  672,   27,   11,   62,   99,   60,   12,  141,    1,   41,  107,
#             11,    8,    0,  257,    1,   75,   16,   22,  259,    0,   84, 1276,
#            239,    3,    5,   59,  916,    3,   80,   74,  207,   30,    4,   86,
#             13,    4,   71,   23,   89,   27, 1694,    7,   16, 2777,   29,   15,
#             70,  107,   30, 2926,    7,   75,   47,    9, 1136,  316,   70,  141,
#             72,   54,  124,  317,   13,   52,   91,   33,   42,  187,    7,   41,
#             11, 2025,   58,    2,   21,    1,   15,  886, 2990,   31,    1,    0,
#              1,   15,   70,  145,  493,  713,  482,  150,    0,    1]),
#   tensor([  0,  24,  51,  67,  89,  96, 116, 143])),
#  (tensor([1, 1, 1, 0, 0, 0, 2, 0]),
#   tensor([  92,  506,   92,    3,   24,   10,  793,   15,  947,  140,   29,    9,
#            943,    1,    3,  779,  134, 1579,   35,  532,  693,   14,    3,   80,
#            112,    2,    0,   15,  202,    0,   24,    9,   50,    1, 1579,  140,
#            914,   53,   27,  181,   21,    7,   24,    3,  269, 1571,   17,   15,
#            642,   13,    7,  365,  197,   43,   79,   37,    8, 1985,    0,   10,
#             48, 1065,    4, 4120,    6,   24,    9,  631,  206,  140,    7,    0,
#            565,    7,  238,  225,  232,    5,   19,  181,   21,  373,    2,    8,
#           1270,  127,   54,   40,  171,  603,    1,   54,  850, 1958,    9,    1,
#             75, 1136,    7,  156,   51,    9, 1049,   43,  365,   60,  252,    5,
#             28,   13,  251,    1,   39,   36,    1,    0,  315,  597,    2,    4,
#           2570, 1304,  310,   13,   15,   12,  100,    1,   23,    5,   28,  674,
#            499,    1, 1334,   92,    3,    0,  567,  344,   11,    9,   23,    9,
#             25,    2,  648,  195,  461,   65, 1962,   11,    9]),
#   tensor([  0,  14,  42,  72,  74,  99, 116, 134])),
#  (tensor([0, 1, 0, 1, 1, 0, 0, 1]),
#   tensor([ 100,   10,   94, 1780,    1,   10,   31,  546,   15, 1118,  104,    1,
#            399, 2106,  729,    0,  324,   55,    0, 1293,   39,   36,    1,    0,
#              0, 1276,  441,  190,  447,    9,   25,  360,  198,   13,   12, 1750,
#              2,  767,  455,  227,  100,    7,  855,   70, 1068,    2,   37,  331,
#             32,  861,   14,  249,    7,    3,   43, 1996,   23,   56,   46,   30,
#           2799,  839,   11,    4,  114,   10,   27,  343,    1,   54,   78,    8,
#            677,    2,   47,  284,    1,    1,  247,  149,    0,  256,    1,    1,
#              1,    1,   14,   22,   56,   46,   89,   44,  903,   29,   21,    7,
#            665,    1,   24,    9,   50,   21,   33,   38,  636,    2,  372,  350,
#            249,    7]),
#   tensor([ 0, 12, 24, 29, 42, 53, 77, 98])),
#  (tensor([0, 0, 0, 0, 0, 0, 0, 0]),
#   tensor([   9,   40,   11,   48,  449,   17, 1739,   70,   13,   32,  497,    1,
#              4, 1217,   16,    8,  118,  501,    1,    3,   80, 3636,    0,   17,
#             22,  401,   10,  466,   54,   53,  711,    2,   21,   17,    8, 1654,
#           2409,    1,  130,  570,    3,   97,    5,   19,   33,  721,   11,   32,
#             12,  127,   54,  349,    5,   19,  741,    4,    0,   20,  550,    1,
#           1938,    1,   75,  377,    5,   19,    9, 2443,    8,  192, 1057,   11,
#            551,   11,  129,    7,    7,    7,    7,    6,    6,    6,    6,    6,
#              6,    6,    6,   82,   83,   62,  127,   20,  293,  782,  170,    2,
#            470,  296,   13,  294,   12,    1,  275,   10,   35,   76,   85,   21,
#             12,  727,   17,  144,  384,   14,   64, 3048,  933,   68,  153,  610,
#              5,   19,  141,  144,  102,  242,   39,   36,    1,    0,   10, 1037,
#             10,   16,  755,  713,   22,    0,  729,   26,   14,   74,   16, 3618,
#             13,   39,   36,    1,    0,    1,    3, 1837,  349,    5,   19,  254,
#              9,    1,   64,    3,  111,   16,   23, 1453,   34,  145,  126,    2,
#             25,   18, 1800,   17,   38,    4, 2312]),
#   tensor([  0,  12,  38,  62,  87, 108, 126, 150])),
#  (tensor([0, 1, 0, 0, 0, 0, 0, 0]),
#   tensor([ 452,   17,  754, 1574,   14,  172, 1088,  127,    9, 1307,    4,   12,
#             14,  464,   15,  154,  447,    1,    0,    3,   79,   99,    4, 1022,
#            186,  654,   48,    3,   24,  288,   57,    1,   73,    9,    1,    4,
#            155,   23, 1303,   61,   30,    4,   86,  220,   98,  296,    0,   13,
#            203,   79,   25,    2,   37,  639,   57,  208,    1,    1,    1,  171,
#            221,    3,    5,   59,  172,   32,    0,   22,  238,    0,    0,   23,
#           2193,    9,   38,  800,   18,  208,    1,    0,  395, 1427, 1462,    0,
#           1902,  309,   54,    0,   22,  157,   66,  121,  235,    9,  113,  340,
#             10,   99,    3,  151,    2,  109,    0,  107,    6,   49,   13,   67,
#             11,   62,   11,  361,  332,    3,  169,   25,  289,   17,  485,  168,
#            562,   72,   18,   26,  310,    1,   22,  392,    0,   16, 2563,  376,
#            166,  194, 2153,  477,   50,    2,   61,    6,   15,  806,   89,   49,
#             13,   67,   11,   44,   96,   11,  361,   23,  152,  144,    2,  823,
#              1]),
#   tensor([  0,  19,  35,  59,  80, 105, 132, 135])),
#  (tensor([1, 0, 2, 0, 0, 2, 0, 0]),
#   tensor([  98,  552,   68,   12,    2,  614,   53,  317,   11,    8,  601,   52,
#              7, 1709,   20,  143,   17,  225,   14,  485,  168,  476,    4, 2333,
#            194,    0,   30,  400,    1,   50,    7,   73,  508,    5,   64,   11,
#            194,   44,  356,  104,  183,  935,   65,    2,  749,  195,  215,    1,
#              9,  108,  869,    6,   12,   42,   90,   10,  607,  264,  205,  208,
#             89,   27,  973,   10,   13,   15,  601,  858,   20,   67,   84,  132,
#             43,   63,    1,   98,  204,  590,    7,  429,   29,   22,    0,  292,
#            165,    1,  341,   56,   46,   10,   15,   12,   89,   49,   42,   90,
#             79,   99,    2,   33,  140,  118,   12,  328,   38, 1855,    2, 1589,
#              6,    6,   73,    9,   11,  583,  118,  712,   10,   46,   14, 1344,
#           1565,    6,    6,   39,   36,    1,    0,   48,    9,    5,  115,  505,
#              4,   85, 1026,   16, 2814,    7,   24,    5,   19,   33,   81,  175,
#             52]),
#   tensor([  0,  13,  31,  52,  79, 101, 127, 138])),
#  (tensor([0, 0, 0, 0, 2, 0, 1, 0]),
#   tensor([  41,    0,    3,   95,  275,  223,   35,    3,  175,   15,  159,  303,
#            154,    1,  583,   16,  532,    1,   12,    0,    0, 1651,   20, 1204,
#              7,    0,    1,    1,    1,   94,   42,  684,   14,    8,  138,   10,
#           1805,   21,    2,  245,  363,   12,    1,  149,  257,   27,  194,  140,
#              1,   41, 2527,    0,    3,  244,   61,  272,    5,   28, 1422,   11,
#             62,   55,   15,   12,   16,   62,  102,   12,    1,   41,  397,   11,
#           2210,   60,  202,    1,   15,    0,  347,    5,   19,  126,    2,  245,
#           1560,    0,   41,    2,  508,    5,   64,    6,    0, 2387,  393,   60,
#             71,   66,  464,   18,    2,  167,  530,    1,    0,    6,    6,    6,
#              6,   12,   38,  598,    2,  768, 1279,   10,  169,   23,   37,    8,
#           1100, 2056,  199,  891, 1966,    7,    0,    7,   39,   36,    1,    0,
#             12,   58,   20,  237,   10,   66,  191,  329,  138,    1,    3,  169,
#             33,  106,   18,   72,   18,   26,   45,  133, 1389,  980,   10,   35,
#           1595,   18,    5,   28,   27,   55,  312,   13]),
#   tensor([  0,  18,  29,  51,  69,  93, 114, 132])),
#  (tensor([0, 2, 1, 2, 0, 1, 1, 0]),
#   tensor([ 166,   75,   25,    9,   42,   90,   60,   12,  333, 1292,   20, 3155,
#             61,   91, 2885,    7,  158,  434,    1,   73,    9,   11, 1366,   32,
#             11,   21,    1,  612,  397, 1682,   83,   51,   18,    5,   28, 1107,
#            244,    6,   34,    5,   93,  217,    9,  103,  273,  318,  146,    1,
#              3, 1404,  277,    9, 1121,   32,  158, 1388,    1, 2523, 2511, 3362,
#              0,   41,    2,  677,    0,  183, 1166,   21,   29,  118,   56,   46,
#              1,    0,   75,  349,    5,   19,    9,   25,  493,    4, 2232,   20,
#             15,   82,  203,   12,   68,   18,  557,  351,   20,  110,  309,  212,
#              7,    2,  411, 4144, 2835,   70,   38,    2, 3363,    0,   13,    0,
#           1054,  346,    1,    3,    5,   59,  112,    2,  260,    8,   12,    2,
#              4,  790, 1601,    1,   72,   32,   16,   65,   22, 1074,   16,  126,
#              2,  135,   10,    9,  865,    6,  764,    0,    0,   13,  281,  776,
#              1, 3593,    0, 2138,    1,   27,  499,    6,    6,    6]),
#   tensor([  0,  19,  38,  61,  74,  97, 109, 124])),
#  (tensor([2, 0, 0, 1, 0, 0, 2, 0]),
#   tensor([  73,    9,    1,  306,   23,    6,    6,   32,   26,    8,  534,  532,
#              0,   17, 2611, 1450,  332, 1069,    0,    1,  206,  723,   79,  135,
#              8,  219,  116,    1,    9,   85,   32,   56,   46,    7,    7,  207,
#             17,    4,    0,   11,  329,   10,  175,   88,   10,   14,    9,  235,
#             21,    8,  113,    1,  340,    7,    7,    7,  315,   11,  206,   50,
#              2,    0,   44, 1257,    3,  229,   13,   44,  995,   32,  909,  465,
#             10,  229,   15,  643,   88,   10,    0, 1216,   10,   17,  163,   10,
#           1034,  208,  941,   10,   31,  196,  514,  234,   17, 1240,   13,  535,
#             30,    0,   29,  193,  899,  495,   31,   56,   46,   10,   31, 1001,
#             10,  495, 2322,   10,  522,   46,    1,   16,    4,  222,    6,   24,
#              5,   19,  123,    2,  255,   15,  192,  954,  113,   11,    8,  803,
#            202,    1,  127,   20,    9,   10,    3,   80,  421,    4,   77,  501,
#              3,  265,    2, 1343,    1,   73,    9,   11,  793,   21,    2,  184,
#            381,    1]),
#   tensor([  0,   7,  28,  56,  71,  90, 115, 134])),
#  (tensor([0, 0, 0, 0, 0, 0, 0, 0]),
#   tensor([  17,  390,   10,  548,  190,   94,  180,  809,  229,  199,   86, 1372,
#            799,    1,   12,  380,    0,  220,  139,  766,   14, 1910,  447,    1,
#             65,  335,  968,  209,    5,   19,  111,    9,   40, 4043,  893,  369,
#             70,    2,  822,   14,   38,    2, 2375, 2973,   92,   20, 1413,    7,
#             72,    9,  169,   33,   21,   13,    4,   12,    6,   15,   89,   49,
#             82,  309,    1, 1323,    9,  175,  214,   88,   66,   94,  285,   20,
#            194,   13,   67,    9,  148,  214,  162,   79, 1359,   33,  214,   88,
#            755,  428,   40,   70,  424,  439,  197,   43,    7,   17,    0,  112,
#              2,  707,   58,   65,   82,   12,   16,  126,    2,   37,  696,    1,
#           2006,   20,    0,  180,   40,    0,   10,    0,    1,  274,  547,   21,
#              2,   67,   10,  125,  317,  483,    1, 2882,  148,   21,  230,  349,
#              5,   19,   50,  468,  126,   13, 1347,   15,  184,   16,  175,   10,
#             15,   12,   42,   90,   14,    3,   33,   31, 1925,    7,   27,  142,
#              2,  149,  104,    1,   30,  389,   77,  292,  271,    7, 1572, 1572,
#            103,  268,    1,  563,    2,   37,    4, 3153,    1,  510,  282, 1031,
#              1]),
#   tensor([  0,  24,  48,  63,  86, 106, 139, 166])),
#  (tensor([2, 0, 0, 1, 0, 0, 0, 0]),
#   tensor([  73,    9,    6,   41,   11,    4,  490,   10,   35,    3,  291,  201,
#             18,    2,   15,  503,   10,    0,   62,  102,   12,    1,   22,  101,
#            964,  608,    1,    3,   25,    8,    0,    1,  146,  217,    1,   75,
#             40,    9, 1139,  143,    2,  156,    4, 1976,   12, 3130,    7,  571,
#             36,    1,    0,   16,  762,   21, 1969,  277,   20,  178,  172,  140,
#             18,    5,  211,   37,  290,   72,    3,  169,   33,   44,  337,   10,
#            142,    8, 1470,   31,   79,   47,    3,   45,  151,    2,  111,    1,
#             63,   31,   77,  391, 1273, 2275,   10,  702,  550,   10,  284,  659,
#              1,  850,   31,  543,   92,    2,   51,   26,  983,    1]),
#   tensor([ 0,  3, 22, 32, 35, 51, 60, 85])),
#  (tensor([0, 0, 0, 0, 0, 0, 0, 0]),
#   tensor([ 174,   66,   25,  223,  649,    0,   13,    4,  413,   66,  368,    4,
#            113, 2551,  484,   10,   35,    4,  580,  267,   25,   27, 2040,   57,
#              1,  151,    2,  109, 1589,    0,  822,    0,    0,    0,    0,   68,
#              3,  557,   30,    4,  114,   10,    3,   26,  148,   15,  164,   87,
#             49, 1167,  127,   15,  352,   87,    8, 1836, 1788,    1,   23,   16,
#            403,   27,  872,    6,    9,   24,   33,    8,  154,  208,   94,    8,
#            456, 2146,    1,   23,  471,   16,  871,    0,   14, 3826,    1,    0,
#           1830,   15, 1696,   17,   22,  238, 1103,   14,    4, 1275,   20,    8,
#              0,  907,   29,    8, 1505,   17,    4,  422,    3,  528,    1,   18,
#             26,   42,  187,  328,    3,  531,    1,  845,   81,    2,   31, 1114,
#             38,  163,   83,   42,  786,   16,   12,  130,  126,    2,  317,  553,
#            100,    7,   72,   27,  254,   61,   43,   14,    3,   53, 1754,    8,
#            474,    1,    3,   47,   27,  151,    2,  595,   57,  452,    1,  331,
#              1,   34,   53,  791,   42,   12,   60,   70,  125,   10,  152,    8,
#            270,   10,   14,   33,  140,  149,  116,    1, 1329,  232,    5,   19,
#            177,   11,   61,    1]),
#   tensor([  0,  31,  35,  58,  84, 104, 125, 155])),
#  (tensor([1, 0, 0, 1, 1, 2, 0, 0]),
#   tensor([1747,   14,   43,   54,  217,   60, 2659,    0,  153,    2,    4,  157,
#           1349,    1,   18,    5,   28,   49,   77,  939,   57,   94,  149,    1,
#            221,  119,   12,   16,    8, 1976, 1043,  249,    0,    0,  136,  352,
#              0,    3,  120,   27,    1,   23,    5,   28,   75,    3,   80,  158,
#           1497,    1,    3,    5,  176,  156,    9,   13,  321,  107,  506,    6,
#             34,    5,  176,   25,   52,   14,   54,  610,    5,   19,  421,    8,
#           1030,  501,    1,    3,    5,   59,    4,  606,   17,    4,  920,    0,
#             14,    0, 1604,  124, 1605,    2, 2120,    1,  110,   30,  237,   44,
#             96,   94,  536,  152,  137,   14,   74,   31,  875,   13,  374]),
#   tensor([ 0,  1, 26, 34, 37, 50, 60, 87])),
#  (tensor([0, 1, 1, 0, 0, 0, 0, 0]),
#   tensor([  65,  216,   23,  128,    8,   12,  991,   13,   52,    7,   14, 3950,
#             18,  504,   21,  102,   12,  127,   43,    3,   25,    2,  123,   11,
#             15,   88,   30,  184,  381,    1,    3,  515,  575,   24,    3,   33,
#            161,   81,   72,    3, 2329,   27,    2,  135,    7,    3,  569, 3364,
#             16,  913,   10,  267,    2, 1003, 1107,   72,  195,  153,  240,    5,
#             19,  312,   58, 1331,  144,   20,  525, 1900,    7,    9,   78,    2,
#            131,    4,  116,   56,   46,   16, 1071,    6,    3,   25,   49,  110,
#             11,    8,  677,    2,  364,   21,   11,  185,   10,   51,  804,    7,
#             55, 1522,    6,   12,    2, 2109,   82,    6,  126,    2,  245,  256,
#              1,   24,    9,   76, 1127,   21,    2,  149,  104,  701,    7,   39,
#             36,    1,    0,  141,    5,   28,    2,  207,   13,   67,   11,  132,
#             12,   42,  187,   14,   54, 1958,  480,    1,    0, 2064,    0, 1723,
#             10,  849,   66,   47,   32, 2030,   22, 3189, 3228,    1,   18,   16,
#           3762,    1,    0,  651,   10,   64,   40,  275,   11,  129,   80,    1,
#            570,    4,  836,   52,   16,    8, 3527,   11,   31,   42,   90,   70,
#              6]),
#   tensor([  0,  30,  45,  69,  96, 123, 143, 159])),
#  (tensor([1, 0, 0, 2, 2, 0, 2, 0]),
#   tensor([   3,   78,    8, 1046,   11,    8,   12,  131,    1,   24,    9,  354,
#             77,    7,  213,   16,   15,   88,    7,    6,    7,    6,    7,    6,
#             51,  216,   32,  142,  561,    7,    3,    5,   59,  417,   83,  937,
#           1358,  215,  183,  368,   11,    8,  154, 1299,    8,  154,   23,   53,
#            135,  660,  924,    1,  435,   40,  158, 1344, 3183,    6,  330,    6,
#             79, 1726, 1144,   37, 2391,   17, 1801,    7,  239, 2620,    6,   41,
#             11,  316,   31,   77,    2,  385,   15,  136,  193,   70,   10,   14,
#             64,   35,    0,   21,   17,  542,  249,    1,  263,   40,    4, 1021,
#            173,   34,  145,  695,    2,    8,  724,  383,    1,   73,    9,   11,
#              4, 1925,    6,    9,    5,  115,  197,    1,  139,    9, 3517,    4,
#            470, 1002,    1,  171,  221,   69,   40,   31, 3483,    1,   35,  331,
#              1]),
#   tensor([  0,  14,  24,  52,  68,  71,  97, 111])),
#  (tensor([0, 0, 0, 0, 0, 0, 2, 0]),
#   tensor([  12,   38,  336,    2,  753,   42,  187,   10, 1152,    2,  542,   10,
#             82,   10,   43,   25,    2,  278,    2, 1754,    8,  474,   14,  658,
#            132,    2,  753,  106,    4,  136,  302,   10,  163,   89, 1166,   21,
#             29,    4,  173,   56,   46,  200,   20,   15,  532,    1, 1429,    1,
#            976,    1,   18,   26,   32,  943,  516,   64,    4,  446,   17,    4,
#            586,  843,    1,  931,    4,   12,   26,   27,   42,   90,   35,  792,
#            230,  453,  308,    1,  404,  345,  697,  396,   68, 1201,  341,   56,
#             46,    1,   12,   42,   90,    7,    7,    7,   15,  406,   16,  234,
#             17,  987,   13,    4,  116,   38, 1317,    2,  443,   41,    8,  511,
#            397,    6,  674,  819,    3, 1698,   38,  598,    2,    0,   74,   31,
#            273,   13,   15,  153,    1,   51,    5,   28,    4,  622,    6,   41,
#              6,  508,    5,   64,   25,  206,   20,    4,  222,   56,   46,  229,
#             17,    4, 2156,    1,  122,  364,   21,   14,    4,  968,   13,   15,
#             12,  183,   24,    5,   19,   33,  195,  259,    2,  177,    1,  986,
#             20,   60,  273,   16, 1906,    6,   39,   36,    1,    0]),
#   tensor([  0,  27,  49,  76,  86, 110, 131, 148])),
#  (tensor([0, 2, 0, 0, 0, 1, 2, 2]),
#   tensor([   3,  274,  172, 2163,    2,   44,  558,  457,   68,  112,    2,  730,
#              8,   12,   13,   39,   36,    1,    0,    1,   25,  265,   30,  389,
#            679,    1,   41,    6,   45, 1295,    0,    1,   31,   70,   58,   20,
#            598,  127,   20,  286,    0, 1766,  262,    1,   31,   54,  145,    2,
#            603,  417,    2,  605,  204,   14,    3,  638,    2,   33,    2,   44,
#              0,    1,  308,   60,  256,  170,    2,  138,   58,   20,    1,  148,
#             27,  315,  139,   11, 1093,  659,    1,   34,   53,   37,  234,   17,
#           2258,    1,   50,    6,   60,  252,    5,   28,   13,  251,    1,   39,
#             36,    1,    0,    0,   41,   11,  299,   17,  158,    0,  133, 1289,
#             11,   64,   73,    9,    6]),
#   tensor([  0,  26,  32,  44,  62,  88,  99, 110])),
#  (tensor([0, 0, 0, 1, 0, 0, 2, 0]),
#   tensor([2712,  166,   14,    0,    0,   44,  558,    1,   51,   40,    4,    0,
#           2049,    2,    0,    4,  101, 3135,    7,   64,    3,   33,   16,    8,
#            643,    1,  174,   10,   18,    5,   28, 1833,    1,  221,  133,  693,
#            307,  920,    1,   72,    9,  108,   97,    5,   19,   25,    4,  322,
#            814,    2, 3680,   23,    3,    5,   59,   30,    8, 2169,    1,   18,
#              5,   28,  792,   65,    3,   24,    5,   19, 1411,   98,  219,    0,
#           1180,  359,    1,  191,   47,    9,   25,  383,   70,    2,   14,   38,
#            448,    2,  294,    0,   91,    0,    7,    1,  194,   82,   62,   11,
#              8,   77,   96,   12,   16,  103,  168,  568,    1,    3,    5,   59,
#            279,  817,    2,   33,    8, 2114, 1112,   30,   32,   96,    1,  124,
#            107,    3,  301,   17,  602,   11,  294,  303,  121,    2,  260,    3,
#             80,   27,   13,    4,  808,    1,   32, 1074,   16,    8, 2737,    1,
#              3,    5,  176,   47,   23,    1,   24,    5,   19,  146,  309,    9,
#            288,   21,    1,   41,    6,  521,   99,    8,  510,  489,   11,   22,
#              0,  571,   36,    1,    0]),
#   tensor([  0,  26,  59,  76,  91, 121, 144, 161])),
#  (tensor([0, 1, 1, 2, 0, 2, 0, 0]),
#   tensor([  40,    9,   58,   20,   22,  965,   10,  166,    7,   51,   16,    4,
#            442,   20,   32,  418, 1584,    7,  634, 3111,   17, 1350,   91,  485,
#              7,   79,  182,    2,  135,    2, 1367,    2, 1277,    0, 3058,    1,
#             31,  214, 2703,   26,  106,  105,    4,   52,  162,   95,  214,   85,
#           1023,  217,   55,   63, 1955,    2,  156,   51,  765,   20, 1811,   34,
#             33,    1,    3,   25, 2752,   23,   15,  795,   43,   16,  170,    2,
#            401, 1113,   53,   47,    1,   41,    6,  806,   14,    3, 3862,  473,
#           1430,  318,   15, 1559,   14,   54,  124,  799,    1,  300,    6,  259,
#            232,    5,   19,  181,   21,  131,  208,  142,  359,  104, 1444,  192,
#           1057,   10,   43,   13,   67,   11,  144,    1,   50,    1]),
#   tensor([ 0, 25, 36, 49, 62, 74, 79, 95])),
#  (tensor([2, 2, 0, 2, 0, 0, 0, 2]),
#   tensor([ 330,   11,   22,  592,  196,   14, 2541,    6, 2572,   53,  128,  139,
#            255,   20,    4,  340,    0, 3366,   73,    9,   11,    4,  324,    6,
#              3,    5,   93,   49,   13,   67,   29,   22,    0,  267,   46,  483,
#             11,  144,   10,   14,   23,    5,   28,   94,  194,  378,   57,   13,
#              4,  159,   52,    1,   95,   18,   10,   41,    6,    9,  108,   45,
#           3976,   21,  137,   72,    3,  169,   42,   12,  307,   12,    3,   87,
#            233,   11,   15,  404,    3,   79, 3502, 3476,   22,  781,  286,   16,
#           2529,   31,  972,  133,    0,  743,   31, 1075,   11,   61,    1,   14,
#              3,   24,    5,   19,  135,  953,  530,  228,    9,  175,   15,  153,
#              1,    3,  277,    9, 1196,    2, 2762,   48,  931,   83,   60,  136,
#            562,  202,    2,   84,   14,  162,  240,    5,   19,  111,  247,    6,
#             63,   39,   36,    1,    0]),
#   tensor([  0,  18,  24,  52,  57,  80,  85, 115])),
#  (tensor([2, 1, 0, 1, 2, 2, 0, 2]),
#   tensor([ 547,   15, 1970,   17,  402,   43,    1,   63,   21,  107,   63,    9,
#             97,    5,   19,   25, 2267,   13, 1156,  700,   10,   47,    9,    7,
#             84,   72,   48,   10,   51, 3526,    7,    0,   16,   13,    6,   63,
#              9,  608,    1,   96,  138,    7,    6,  399,    2, 1198,    5, 3338,
#           1686,    0,    5,   29, 2260,    1,    1,    1,   55,   39,   36,    1,
#              0,   89, 2369, 1142,  189,  478,   10,   38,  113, 2419,    1,  830,
#             20,  499, 1284,   39,   36,    1,    0, 2840, 2844,   23,   79,   37,
#            118,   55,  580,   61,   50,    6,    3,   78,    2,  373,    2,    8,
#            709,  155,  199,    3,  647,   15,  208,  238,  194,  848,    1,  118,
#             56,   46,  107,    1,   41,    6]),
#   tensor([  0,   8,  36,  43,  61,  81,  88, 107])),
#  (tensor([0, 0, 0, 1, 0, 2, 1, 0]),
#   tensor([   4,  173,  134,  200,    3,    5,   93,  178,    0,  189,    1,    3,
#              5,  211,  306,   15,  357,   81,    1,   73,    9,   11,  424,   15,
#             88,   17,  542,    6,  824,   51,   22,  286,  253,   10,    3,   26,
#           1061,   13,    4,   12,    6,   15,   71, 1566,   99,    8,    0,    0,
#             16,   32, 1540,    7,   72,   48,   10,   53,   32, 1359,   37,    8,
#            160, 1105,  484,    1,  169,    9,  254,   21,   72,   98, 1094,   40,
#            310,   13,    8,   12,   58,   20, 1765,  129,  243,    1,    3,  487,
#             11,  206, 1753,  361,   99,  267, 1135,    2,   15,  461,   14,   26,
#            148,    2,   85,   56,   46,   86,  155,    0,   16,  356, 3787,    3,
#             80,   27,  538,   55,   34,  112,    2,    0,   57, 3832,    1,    0,
#              1, 1499,  328,   14,   26,  148,   23,   69,    5,   28,  248,   54,
#             24,   47,   55,   54, 2226,    3,  186,   11,  206,  723,    7,    7,
#              7,  529,   46,    7,    7,    7]),
#   tensor([  0,  19,  41,  64,  82, 101, 106, 121])),
#  (tensor([0, 0, 1, 1, 0, 1, 1, 1]),
#   tensor([   3,  151,    9,    2,  278,   11,   15, 3170,  484,   30,  768,  114,
#            127,   22,  320,  148,   21,   15, 2413,   12,  430,   30,   14,   18,
#           1721,   66,   69,   40,  198,  496,   10,   54,   45,   25,  645,    1,
#            563,   72,    3,    5,   59,  417,    8,   80,   12,    4,  389,    9,
#             24,   47,   16,    0,    4,  113,    1,   65,  335,   40,  229,    7,
#              6,   23,    5,   28,  281,    6,    7, 1221,    6,  651,  754,   10,
#           3017,    6,   40,    9,  108, 3088,  112,    2,  647,  215,   14,  357,
#              7,   48,   72,    3,    5,   59,  134,  294,  303,   45,   77,  694,
#              2,  432,   35,   27,   13,   15,  219,   12,    2, 2935,   80,    3,
#             74,  295,    2,  255,    4,  831,   17,  432,   60,  252,    5,   28,
#             13,  251,    1,   39,   36,    1,    0,   75,    2,   37, 1028,   13,
#             15,  157, 1810,   10,    3,   80,    0,    4, 1547, 2904,    1,   12,
#              2,    0,   39,   36,    1,    0]),
#   tensor([  0,  25,  55,  61,  74,  85, 116, 128])),
#  (tensor([0, 0, 0, 1, 1, 1, 0, 1]),
#   tensor([   3,    5,   59,  429,   23,    4,  155,   30,    4,    0, 1394,  338,
#            147,   17,  225,  863,    2,  997,   64,    0,   60,   12,   26,   42,
#             90,   66, 2098,    0,    1,    3,   80,   17,  139,    0,    1,   76,
#            235,   21,  292,  566,    2, 1194,   21,    1,   42, 1363,   70,   10,
#            793,   58,  298,   10,  125,   27,  547,    4, 3502,    1,    1,    1,
#            609,   65,   16,   23,  738,    7,   78,    2,  131,  238,    1,   25,
#            873,  305,  413,    1,   47,    3,   78,    2, 3827,   13,  101,    2,
#           1659,  131,  484,    7,   91,   24,    3,   47,  208,    7,  397,  867,
#            212, 1164,   43,  310,   17, 2159, 1008,    6,   39,   36,    1,    0,
#             39,   36,    1,    0,   45,  918,   15,  196,   13,    4,  489,    9,
#            217,    1,   24,    8,  534,  327,   50,   21,  141,    7,   32,   56,
#             46,   16,  434,    1,    3,    5,   59,   30,    4, 3821,   20,  167,
#            228,    4,   70,   40,    0,    1,    3,   45,  120,   10,   65,   24,
#              3,  146,    7,   47,  117,   25,    2,  279,  407,   21,    7]),
#   tensor([  0,  20,  44,  66,  94, 112, 122, 150])),
#  (tensor([0, 1, 0, 0, 0, 0, 2, 2]),
#   tensor([ 166,   43,   23,    4,  995,   89,   49,  207,  141,   11,  106,  132,
#             10,   69,   40,  470,  205,    1,  998,   10,    4,  166,  483,   16,
#              0, 3633,    0,   16,    8,   84,  576,   63,   84,   63,    0, 2488,
#            218,    1,    3,   24,   50,    4,  495,   91,  632,    8,   71,  164,
#              1,    1,    1,    3,   24,    5,   19,   47,  462,    1,   24,    9,
#             50,    7,   65,   83,    9,  369, 2613,   14,    0, 1193,   14,   33,
#            206, 1190,  101,  856,    2,   47,  195, 3099,    4, 1323, 1663,   16,
#            510,    6,   39,   36,    1,    0,    3,  393,    4, 1702,  246,  841,
#             17,    2,  314,  185,  283,    1,   18, 1436,   10,   31,  323,    1,
#              4,  155,  100,  148,  206, 3845,   83,    8,  471,  131,    1,    1,
#              1,  162,  220,  162,   79,   78,    2,   33,    8,  677,    1,  366,
#            110,   11,    4,  677,  162,  378,   57,   13,   21,    1,   73,    9,
#              1, 2077,   73,    9,    1,  188,  690,    1]),
#   tensor([  0,  25,  62,  80,  90, 118, 142, 145])),
#  (tensor([1, 0, 0, 2, 0, 0, 0, 0]),
#   tensor([  60,  252,    5,   28,   13,  251,    1,   39,   36,    1,    0,  408,
#            163,   10,   65,  188,    3,    0,    0,    6,   23,    5,   28,   72,
#             18,   16,  178,  823,   14,   72,    3,   24,  178,   33,  189,   56,
#             46,    0,  935, 1330,   57,    6,   23,    0, 1686,    1,   45,  149,
#            501,    2,  407,    2, 1877,   75,    3,  109,   29, 2532,   10,   41,
#             11,   27, 1611,   23,    9,   24,   27,    0,  178,   15,  153,    2,
#             15,  271,   10,   68,   88,  293,  256,    1, 2860,    0,    4,   56,
#             46,  100,   16,    0,   10,   12, 3543,   10,   27, 1220,   10,  276,
#             11,   62,   14,    4,  101,  225,  216,   27,  142,  181,   21,   67,
#             60,   12,   26,  275,   29,    9,   14,   34,  151,    2,  131,   60,
#            198,   91,  362,    2,  294,  303,    1,   24,    9,   50,    7,  915,
#             40,  282,    1,  499,    1,   43,   89,   49,  148,    9,   24,    5,
#             19,    0,  414,  153,   94,  230,   26,  148,    2,  317,  161,  136,
#            257,    1,  230,  433,  161,    2, 2439,    1]),
#   tensor([  0,  11,  20,  38,  58,  82, 108, 135])),
#  (tensor([1, 0, 0, 1, 0, 0, 0, 0]),
#   tensor([1326,    2,  294,  303,    1,    0,   83, 1462, 2493,    1,    0,    0,
#             66,    3,   24,    5,   19,    0,    4,  204,   77,    1,  349,    5,
#             19, 2984,    1,    1,    1,  434,   56,   46, 3618,  106,    4,  859,
#            516,    4,  776,    1,    3,   26,  234,   13,    4,  405,   11,    1,
#             62,   29,   31,  337,    6,   98,  875,   13, 1925,   11,    4,  210,
#             13,   61,   68,   54,  584,   17,  502,    7,  511,   20, 1051,  210,
#            141,   34,   40,  112,    2,  135,   92,  449,  447,   38, 3105,    5,
#           3991,   92,  512,   11, 2592,  100,    1,   79,    9,   50,   61,    7,
#           3371, 3391,   42,   90,   12,   32,   80,    1,   69,   26, 1342,   12,
#              2,  336,  100,  117,  220,   26, 1318,   58,    1,    3,   87,    2,
#            632,  574,  164,   10,  117,   78,    2,  270,   21,    1,  776,   91,
#             31,  776,   10,   22,   56,   46,   16,    8,  623,    1,   96,  123,
#             52,    2,  373,    2,  167,    7,    3,   53,  124,  109,   22,  104,
#            107,    1,   48, 1534,    3,   24,    5,   19,  142,  528,    9,  108,
#             42,   12,   15,  363,   12,   94,    3,  317,    4,  159,  369,   10,
#             66,  235,   21,    8, 1185,  271,  340,  604,   50,   35,   37,  559,
#             94,   44,   96,   85,   29,  117, 3010,   57,   29,    8,    0,   14,
#             31,  797, 1066,   92, 2990, 2746,  573,    1]),
#   tensor([  0,  29,  53,  73,  98, 130, 158, 187])),
#  (tensor([0, 0, 1, 0, 0, 0, 0, 0]),
#   tensor([   0,   14,    0, 2735,   48,   31,   10,    3,   24,    5,   19,   47,
#             18,  208,    1,   40,   98,   70,  424,  586,  100,    7,   12,   26,
#             42,   90,   10,   49,   13,   67,   11,  106,   44,   96,    1,   51,
#            517, 1720,   11,    0,    7,  240,    5,   19,  313,   17,  212,  358,
#            592,    7,   75,   16,    8,  327,  538,  498,    8, 2716,   27,   33,
#              4, 2659, 1013,    7,  240,    5,   19,  128,  814,    3,  595,   57,
#              0,   15, 4024,   88,  924,  191,  162,    5,   28,   74,  452,   17,
#            586,    1,  556,  309,   80,   29,  204,  495,    1,   54,  145,    0,
#             10,   14, 3018,    1,   75,   26,   12,  488,    2,  767,   42,   90,
#             11,  129,   14,   51,   47,    3,   47,    2,  297,    1,  655,   11,
#              8, 3217,    1,   41,  450,  151,    2,  371,   32,  225,   60,   56,
#            258,  311,   16,  657,  857,    2,  425,    0, 1331,   55,  322,  185,
#              1,   32,   16,  427,    0,   24,    5,   19,  123,    2,  321,   32,
#             77,  140,   62,  102,  242,    0, 3357,    0]),
#   tensor([  0,  15,  35,  48,  78, 100, 123, 145])),
#  (tensor([1, 0, 1, 2, 1, 0, 2, 0]),
#   tensor([1330,  203,  314,   55,  553,    7,    7,    3, 1120,   44,  208,  270,
#            467,   54, 1241,  505,    4,  164,   26,  515,   10,  277,   54,  339,
#              4,  323,   38,   22, 2277, 1295,   81,  633,   38, 3255,    2,  822,
#              2, 1272,   13,  724,    1,  229,  384,    1,  557,  384,    1,  180,
#            325,    1,  319,  973,    6,    6,   76,   50,   39,   36,    1,    0,
#            286, 1002,  107,  821,  221,    0,    1, 2460,    0,   40,   99,  134,
#             44,  995,   69,    5,   28,   31,  583,  501,   92,   44, 1204,  991,
#              1,   68,   40,    9,  469,   81,    2,    7,    9,   25,    8,  764,
#           1601, 1936,   56, 3469,  170,    2,  372,   14,    0,  245,    9,    6,
#             79,   37,  118,   72,    3,    0,   26,  179,    2,   15,  806,  183,
#             16,  134,   17,    4,  246,  238]),
#   tensor([  0,   7,  29,  31,  54,  60,  85, 108])),
#  (tensor([2, 0, 1, 2, 2, 0, 0, 0]),
#   tensor([  13,    8,  396,  940,   60,  180,   16,  902,    1,   24,    5,   19,
#            313,  475,  118,  518,   83,   60,  385,    1,  230,    5,   28,  421,
#             64,  230,   24,   11,   61,    1, 1165,  202,    1,    3, 1514,  755,
#           3318,   14,    0,   14,    3,   80,   48, 1281,    1, 3607, 3500,    1,
#            382,    1,   79,   99,    2,    0,   23,    3,   26,   15,    2,  400,
#            229,    4,   86,    1,   51,   16,  179,   11,  400,    1,   78,   50,
#            239, 3188,   10,    0,    1,  981,   14, 2713,    1,   41,   48,  188,
#             11,    4,   50,    1,   62,  102,  242,   14,    3,  175,   15,    0,
#              4,   48, 2289,    0,  218,   14, 3746,  286,   45, 2980,   15,  472,
#             38,  542,    2,    0,    1, 4010,    0,   16,   64,    9,   47,    1,
#              1,  437,    1,    9,   24,    5,   19,  444,   14,  181,  143,  111,
#             23,    9,    5,   93,   95,  215,   23,   25,   49,   13,   67,   11,
#             62,    7,    7,    6,    6]),
#   tensor([  0,  30,  57,  72,  77,  88,  96, 121])),
#  (tensor([0, 1, 2, 0, 0, 0, 0, 0]),
#   tensor([   8,  270,   14,   12,  901,   91,  149,   12,   13,    8,  375,  104,
#             30,   22, 3655,   11,  100,    1,   96,  658,   16,  158, 1714,  763,
#            617,   10,  183,   16,   22,    0,   11,    0,   29,    0,    0,   17,
#            706,  843,    7,  291,   95,  189,    1,   41,    6,    3,   25, 1104,
#            774,  231,    1, 1439, 2252,    8,  889,   10,  453,    2,  114,   10,
#            276,    1,   76,  371,   32,    6,   91,   76,   50,    6,  130, 2366,
#             15,  119,   57,    0,    2,  314, 3734,  138,  127,   20, 2460,    7,
#            293,  256,   10,  172,  140,  132,  102,  242,   31,  362, 3849,   65,
#           1542,   40,  995,    0,    0, 1945,   14,    0,    7,  731,   25,  272,
#              0,   14, 1419,  198,  168, 2867,   16,   18,  331,   11,    8,   12,
#            380,    2,  379, 1734,   83,  210,  366,   54,  135,   33, 1430,  105,
#              4,    0,    7,    3,   26, 2216, 1073,  280,   23,    5,   28,    4,
#              0,   20,   51,    4,   12,  380,  148,  214,    1]),
#   tensor([  0,  23,  39,  45,  70,  95, 114, 139])),
#  (tensor([1, 1, 0, 0, 0, 1, 0, 0]),
#   tensor([   3,    5,   59,  710,   11, 3381,   17,  402,  478,  574,    6,   39,
#             36,    1,    0,  126,    2,  443, 1373,    6,    3,    5,   59,   27,
#            236,   72,    3,    5,   59,  275,   43,    1,   17,    8,  225,   30,
#            114,  112,    2,  177,   18,   58,    1,    4,  350,    3,   24,   33,
#              2,  372,    4,  224,   84,  887,   23,    5,   28,  692,    1,   74,
#            232,    5,   19,  109,  178,  107,    1,  563,   99,    9,  108,   25,
#            103,  205,  168,  304,  530,    1,  158,  429,    3,  394,    5,   19,
#            738,    2,  131,  198,   94,  620,   17,  384,  208,   11,    8,   12,
#            129,  243,    1,   16,   23,    4,   12,   11,  129,    7,    4, 1332,
#            299,    4,  669,   17,  598,   30,   32,   80,  433,    2,   37, 2648,
#              1,  170,    2,  221,  133,   10,    3, 1192,   29,  204,  210,   15,
#           1239,   26,  328,   14,   15, 1520,  464, 3479,    2,   15,  159,    0,
#             14,    3,  349,    5,   19,   33,    8, 1292,   12,  131,   38, 3806,
#              1,    1,    1,   41,    6]),
#   tensor([  0,  15,  20,  53,  78,  99, 106, 131])),
#  (tensor([0, 0, 0, 0, 1, 0, 1, 2]),
#   tensor([  15,  157,   16,  933,    1,    3,    5,   93, 1034,   15, 2012,   10,
#           1313,    8,    0,    1,   74,   31, 1315,   91,  196,   38, 1942,  157,
#              1,  235,   61,  206,  103, 2942, 2545,   83,    0,   16,   23,  127,
#              0, 2884,    9,    2,    0,   18,  253,   13,    9,  951,  392,   23,
#            117,  109, 1507,   38,  390,    2,    0,    1,   68,    3,  398,    2,
#            226,   18,  253,    9,   47,   27,    1,   25,    9, 1400,    7,   75,
#            240,    5,   19,  675,    8,  743,   11,    0,    7,   51,   16,    4,
#           3028,   23,    0,   32, 1693,    7, 3413,    3,   78,    9,    2,  288,
#             81,   17, 1115,    2,  146,    1,   24,    5,   19,  528,   65,  335,
#            624,  215,    9,  229,  742,   14, 2631,   29,   31,  451,   11,   12,
#             42,  684,  581,   58,   20, 1675,    6,  665,    1,   15,  717, 2432,
#            347,    5,   19,  916,   57,   13,   15,  212,  358,   11,   15,   12,
#            129,    1,    1,    1,   50,    6,    7,  840,    0,  118,   41]),
#   tensor([  0,  25,  41,  71,  91, 102, 129, 153])),
#  (tensor([1, 0, 0, 2, 2, 0, 0, 0]),
#   tensor([1522,    6,   60,  252,    5,   28,   13,  251,    1,   39,   36,    1,
#              0,  213,   40,   60,  625,    7,   71,   16,  141,   12,  253,   18,
#              5,   28,   74,   13,   52,   10,   35,   34,  122,   20,   49,  137,
#              4,  388,  144,  283,    1,   45, 1707,  132,    1,   51,   16, 2812,
#            123,   52,  197,   43,    7,  122,    3,  658, 2382,    2,    4,  114,
#             46,  483,    7,   32,  504,   21,  396,    1,    3,  277,  491,  610,
#              5,   19,  660, 2021,    1,   41,    6,  217,    9,  146,  115,  184,
#            296,    1,   77,   20,   15,  157,  209,    5,   19,  201,   18, 1079,
#             15,   12,   10,  277,   18,  130,  727,  141,  129,   10,   92,    3,
#             26,  148,    3,  120,  480,    1,   95,    8,  889,   81,  505,   23,
#             22,  401,  240,    5,   19,  262, 2763,   11,  101,    0,   50,    6,
#            101,   53,   37, 2456,  137, 3101,    4,  262,   16,   29,  293,  782,
#            384,   86,    0,   14,  751, 1029,   38,   56,   46]),
#   tensor([  0,  13,  41,  63,  77,  86, 110, 137])),
#  (tensor([2, 2, 2, 0, 1, 0, 0, 0]),
#   tensor([  54,  848,    4,   71,    6,  201,   18,    6,    6,   22,  104, 1566,
#           1742,   14,   22,  418, 3667,   16, 1285,  784, 2818,    1,  274,   57,
#              4,  118,  177, 1760,   58,    2,    0,   30,    0,   11,  635,   33,
#             61,  140,  100,  351,   20,  129,   84,  142,   72,    8,  477,  102,
#             12,    6,   63,   75,   25,   21,  321,    8,   71, 1617,   69,   16,
#              8, 2407,  262,    7,   61,    1,    3, 1104,   22,   56,   46,  311,
#              1,  181,   21,  111,   72,    9,   78,    4, 1178,  165,    1,    3,
#             24,    5,   19, 1676,    2,  254,    9,   65, 1172,   15,   71,    5,
#             28,  319,   16,    1,    3,   24,    5,   19,  142, 1635,   57,   44,
#            186,    1,   51,   80,    3,  624,  113,   11,    7,    7,  607,  264,
#            205,   79,   27,   25,  201,   21,  615,   13,   52,   11,   15, 1160,
#              1,  279,  209,    5,   19, 1406,  152,    8,  420,   10,  233,  834,
#             13,  351, 2113,  431,   10,   68,  120,   96,   67,  231, 1345,    4,
#           2156, 2047,    7,   25,    9,  523,   20, 1190, 4035,  516,  133,    7]),
# ...
#             97,    5,   19,  258,   83,    9, 1735,    4,  852,  555,  413,    9,
#            278,    8,  511,   11,    1, 3503, 3503,    1,  653,  163,   12,   89,
#             49,  110,   11,  144,   30, 1467,  110,   11, 1660, 1796,    0,    1,
#            312,   13,   10,  181,   61,  317,    6,   60,  252,    5,   28,   13,
#            251,    1,   39,   36,    1,    0,  118,   10,  125,  254,   21,   65,
#              9,   53,  371,   18,    7, 2523, 2511, 3390,    0,   18,  240,    5,
#             19,  719,   21,    2,   67,    1,   23,    5,   28,    4,  323,    1,
#            174,    6,   45,    8,  513,  144,   94,   15,  444,    1,  162,   26,
#            295,    2,  733,  214,   12,    1,   41,    6,   45, 2331,   30, 1044,
#              5, 1440,   86,  580,    1,   75,   97,    5,   19,    9,  354,    8,
#             56,   46,  386,    2, 1697,   15,  795,    7, 1213,  935,    1,    1,
#              1]),
#   tensor([  0,   8,  34,  55,  66,  81,  96, 116])),
#  (tensor([0, 1, 1, 0, 0, 0, 0, 2]),
#   tensor([1950,    6,    6,  274,   22, 1544,  177,  710,   14,   97,    5,   19,
#            138,   60,   70,   84,  150,   63,   14, 1853,   47,    9,   25, 1439,
#              0,   17,    4, 3471,   13,   22,   70,    7,   34,   40,   13,   12,
#             14,  145, 1643,    2,    4,   86,   24,    9,  675,   98,  543,    7,
#             42,  187,  105,    4,  116,    4,   12,  165,   26,   10,   76,  567,
#            292,    2,  760,  147,   15,  905,   83,  317,   52,   66,  184,   52,
#              1,   76,   50,    6,   31,  153,   10,   31,  116,    2,   33,  189,
#              2,   56,   46,  228,   80,   32,  243,    6,   50,    6,    6,   49,
#            112,    2,  373,    2,  155,   11,  132,   83,   15,   42,   90,   12,
#             35,  856,  334,  603,    1,   65,   47,    3,   33, 1928,   20,    9,
#              7,   41,    6]),
#   tensor([  0,  20,  32,  48,  50,  73,  95, 121])),
#  (tensor([0, 2, 1, 2, 1, 0, 0, 0]),
#   tensor([  16,    4,   42,   90,   77,   73,    9,    1,  118, 4076,  236,    1,
#            288,   11,    8, 3257,   14,    3,   53,    1,  150,  699, 1889,   12,
#             14,  525,    1, 2721,  289,    1,   53,    4, 2976,   37,  310,   13,
#            292,  700,    7,    3,   24,    5,   19,  274,    0,    9,  108,   64,
#            119,    1,   24,    3,   33,  241,    4, 1137, 1751,    7,    3,  274,
#            438,   22,   50,  225,   84,   63,   55,   14,   18,  888,  505,   54,
#             40,  171,  603,    2,   50,   66,    2,   85,   81,  102,  242,    1,
#             11,    8,  302,   43,    6,    3,  339,    4,    0,   26,   27,    2,
#            984,   10,   35, 2590,    8, 1416,   81,    2,    4,  114,    2,  409,
#            161, 1662,  722,  394,    5,   19,   44,  467,    1]),
#   tensor([ 0,  5, 10, 20, 30, 39, 58, 89])),
#  (tensor([0, 2, 1, 0, 2, 0, 0, 0]),
#   tensor([  96,   30,    4,   86,    1,  499,    6,   40,   69,    0,   30,  237,
#              7,    3,   24, 1909,  945,    0,   35,   27,    0,    1,    0,  151,
#              2,  156,   51,    4,  540,   79,   37,    2,  131,    2,    4,   12,
#            124,   17,   15,  532,   25,    3, 2112,   29,  583,  434,   56,   46,
#             10, 3768,  218,   14,  545,   20,  258,    0,  119,   10,  184,   17,
#           1379,    7,  288,   21,   76,   32,  104,   16,    0,   73,    9,    0,
#            368,   11,  384, 1414,   14,  556,   17,   81,   18,  748,    5,   19,
#            152,  546,    2,   33,    2,    4,   86,  168,    4,   12, 3093,  816,
#              1,    1,    1,    1,  144,  134,   52,   55,  144,   13,  535,   48,
#            449,    3,   25,    8,  340,   38,    8,  458,  202,   23,   26,   82,
#              1,    3,  627,    3,   87,    2,  379,    2,  167,   13,    4,  101,
#              2,  255,   18,    1,   16,   23,   27,  872,    7]),
#   tensor([  0,   5,  22,  36,  62,  69,  80, 109])),
#  (tensor([2, 0, 1, 0, 0, 0, 1, 0]),
#   tensor([ 885,   10,    0,   10,    0,   10, 1071, 3540, 1083,   83,  184,  645,
#            239,   10,   14,  393,   44, 2157,   17,   51,    3,   26,  421,    1,
#              3,  567,  344,   11,  166,   47,    3,   78,    2,  255,    8, 2593,
#            163,  667,  358,   11,   15,  820,  426,  947,   10,   91,   24,  230,
#            312,   17,   29,   21,   13,   15,  358,    7, 3018,   66,  559,    6,
#            489,    2,    8, 1972,  969, 2074,   15,  192,  262,  571,   36,    1,
#              0,   75,   25,    9,  124,  848,    8,   71,   11,   21,    7, 3369,
#              0,    0,   26,   45,   13,   67,   29,    9,   64,   11,  193,   62,
#             14,  125,   95,  378,   57,   13,    1,  408,   15, 1213,    1,  315,
#              2,   11, 1449, 2024,  448,    2,  402,   17,  102,   12, 2161,   11,
#            495,   14,  834,   11,    8,    0, 1247,    1,   98, 1142,   91, 2919,
#             62,   13,   67,    2,  131,    8,   42,   90,   12,    1,  755,  428,
#              6,    6,    6]),
#   tensor([  0,  24,  29,  56,  73,  86, 107, 132])),
#  (tensor([0, 2, 1, 1, 0, 1, 1, 1]),
#   tensor([  65,   24,    3,  373,    2,    8,  673,    7,   78,  260,   88,   82,
#            191,    1,  259,   14,  150,   40,  547,   21,  375,  518,    6,   95,
#            378,   57,   13,  679,    3,   53,    1,   73,    9,   11,   30,  389,
#           1129,   21,   81,   63,  224,  168,  425,    1, 1585,   10,   23,   79,
#            801,   75,  180,  209,    5,   19,  697, 2740,    0,   68,   34,    0,
#             18,   58,    1,   18,   26,    8,  477,    0,   30,  159,    1,   60,
#             12,  380, 1340,   23,   34,   25, 2234,  110,   11,   61,   11,   23,
#             12,   48,    3,  244,   34,    5,  176,  128,   18,    1,    3,  233,
#             18,   13,   61,  399,  392,    1,   97,    5,   19,  156,    8,   42,
#             12,  489,   84,    0,    4,    0,   17, 1946,   30,  869,  853,    0,
#              0,   66,    4, 3535,  990, 1528,    0,   39,   36,    1,    0,    4,
#            664,   71,    1,   12,   38,  588,    2, 1743,   39,   36,    1,    0,
#             61, 1894,  195,  296,   92,  934,   71,   13,  388,    2,  719,  363,
#            210,   38,  204,   12,    2,  321,    1,  692,    1,  339,    1]),
#   tensor([  0,  28,  44,  71,  94, 111, 131, 144])),
#  (tensor([2, 0, 0, 0, 0, 0, 1, 1]),
#   tensor([1221,    6,  618,    3,   87,    8,   12,  100,    6,  887,   69,    5,
#             28,  334,  179,   52,    6,   25,  803,   30,    0,   62,   13,  405,
#             17, 2099,   14,   74,   24,    5,   19,   33,    8,  196,   94,    8,
#            302,    1,  428,  184,  311,    7, 2760, 1092,   21,   15,   88,   74,
#            847,    5,   19,   49,  423,    1,   14,   82,  184,  489,   13,  951,
#              0,   27,  299,    1, 2068,    9,    5,   93,   49, 1380,    0,  105,
#             11,  224,   12,  200,   10, 1456,  720,  180,   14,    0,    1,  203,
#             59, 1898,    6,  213,   40,   60,    0,    7,   29,    8,  661,   14,
#            106,    0,   40,  175,   14,  425,    0,   10,   64,   32,  138,  560,
#            659,   30,    4,   86,   10,   91,  142, 1078,    4,  841,    6,   31,
#           2376,   57,   17, 1409,    6,    6,    6,    0,    6,   39,   36,    1,
#              0,    0, 2503, 1334,   18,    5,   28,   11,  129,    1]),
#   tensor([  0,  21,  39,  65,  87, 100, 127, 135])),
#  (tensor([0, 0, 1, 1, 1, 0, 2, 0]),
#   tensor([ 171,  102,   12,   43,    1,  630,   10, 1248, 1757,  639,    1,  169,
#             27,   25, 1254,  519,    1,  606,  179,   21,  122,    5,   93,  705,
#            198,    1,    0,   75,  216,   18,  152,   55,  460,   11,    8,  160,
#           1627, 1082,  413,    2,   37,  217,   58,    7, 3400,    0,   24,    9,
#            288,   10,   48,    3,   24,  146,    9,    7,   41,    1, 2469,  369,
#              4, 1458, 1730,   94,    8,  926,   14,   45,  648, 1304,   66,    8,
#           1538,   23,  253,   85, 1095,   16,  742,    1,    0,   24,    3,  631,
#              0, 2579,   20,    0,   13,    2,   15,   12,    7,   47,    9,  111,
#             23,   22,  175,  184,    0,   39,   36,    1,    0,  240,    5,   19,
#            177,   13,  867,    7,   18,    5,   28,    8,   39,   36,    1,    0,
#           1148,  475,    1,    3,   97,    5,   19, 1130, 3939,   10,   35,   18,
#              5,   28,  139,    2,  111,  167,    5,   28, 1073,    1,   63,    2,
#            778,   18,   64,  137,   10,   22,   12,  539, 1050,    0,    0,    4,
#             12,   10,  142,   68,    4,    0,  145,    0,    1,    0,   17,   31,
#            698]),
#   tensor([  0,  27,  46,  56,  81,  93, 120, 143])),
#  (tensor([0, 0, 1, 2, 0, 0, 0, 0]),
#   tensor([   3,  265,   23,    1,    9,  745,    2,  494,   21,   44, 1190, 2869,
#             11,    8,  160,  164,   91,   37,  452,  309, 4071,    1,  294,   52,
#             10,  136,   52,    1,  157,  645,    7,  232,    5,   19,  387,  134,
#           1532,  107,    6,   30,  389, 1096,  804,  835,  358,  153,    6, 1051,
#             20,    0,    0,    0,   99,    0,  122,  260,    8,  116,    2,    0,
#            212,   20, 1082,  809,   14,  305,  413, 2148,    1,  661,   16,  171,
#            456,    6,  222,  104,  352,  178,    1, 1774,    3,  156,   18,   10,
#              3,  151,    2,   33,   13,  195,   71,    2,  619, 1565,   66, 1393,
#              1,   84,   14,   54, 1143,   13,   23, 1312,   63,  187,   82,   11,
#             62,    1,  227,  877,    2,  402,   16,   43,   80,    1,  120,    9,
#            437,  647,   15,  157,    7,    7,    7,   13,   67,   11,   62,    1,
#              1,    1,   95,   44,  155,   10, 1710,    0,   21,    2,  131,    0,
#             12,    1,    1,    1,  148,   18,   79,   37,  190,   10,  190,  102,
#            242,   10,  110,   33,   12,  241,    4,  272,  158,    0,    3,    5,
#             59,  316,    8, 1821,   52,   29,   12,  264,  205,   92,    4,  558,
#            457,  253,    9,    5,  115,    0,  589,    1,  130,   10,   43,    7]),
#   tensor([  0,  28,  54,  74, 105, 127, 159, 164])),
#  (tensor([1, 0, 0, 1, 0, 0, 0, 0]),
#   tensor([ 231,  131,   10,    3,  531,    1,   39,   36,    1,    0,  331,   15,
#            412,  398,  100,    1,    1,    1,    1,  762,   57,   30,    1,   80,
#             94,  562,   67,   52,    1, 2861,   39,   36,    1,    0,   51,    5,
#             28,    4,  138,   72,    4,  286,  347,    5,   19,  282,    7,   65,
#             47,    3,  111,   72,   15,   12,   26,    0,    8, 3596,   12,    7,
#             18,   16,  699,  568,   23,    4,  866,   30,    4,  163,  164,  669,
#             17,    0,  610,    5,   19,    0,  195,  554,  832, 1314,    6, 2066,
#             73,    9,   11, 2367,  212,   12,   32,  243,  199,    0,   34,   87,
#             31,  625,    1,  481,  391,  271,   35,   31,  463,    1,  279,  186,
#             11,  267,    1,  136,  202,   87,  329,  138,   14,  267,   55,   48,
#            485,   11,   42,  786,    7,  136,  202,   13,    1,    1,    1,  434,
#             56,   46, 1180,   17,    8,  527,    6,  141,    3,  312,    6]),
#   tensor([  0,  10,  34,  47,  60,  84, 100, 125])),
#  (tensor([0, 0, 2, 0, 0, 0, 0, 0]),
#   tensor([  60,   12,   26, 1453,  370,    2,  317,   30,  227,   66,   43,   34,
#            232,    5,   19,  317,  309,    1,   32,   16,    4,  574,   52,   32,
#             89,  560,    3, 1034,    8,   82,   88,  941,   13,  943,    6,   15,
#             12,   26,   42,   90,   14,    3,  124,  453,  953,    6,    9,   25,
#              4, 3842,   86,  380,   30,  553,  114,   86,  197,   43,    1,  833,
#            268,   14,  162,   16,   74, 1456,   29,  395,    1,    3,  277,   48,
#              1,  628,   44,  384,   12,    2, 1343,    4,  114, 2098,   35,   18,
#              5,   28,  171,  102,   12,   11,   23,    6,  213,    5,   28,   15,
#             88,    7,   17,  225, 2618,   30,  382,    1,  250,  313,   85,  150,
#              1,  150,  253,  379,    2,  250,    1, 2268,   56,   46,  116,    2,
#           1151,   57,   14,  647,  153,    1,   15,  806,   89,   31,  972,  722,
#             14,   31, 1031,    1,    0, 2063,    2,    0, 1936,  126,   81,    2,
#             86,  468,  327,   26,  102,   12,    7,  522,   46,   11,   64,   20,
#            183,  799,   13,   52,    6,    6,    4, 1264, 1403,    9,    5,  115,
#           1374,   11,   10,  166,    1,  204,  499, 3180, 2292, 2483,   13,  133,
#              1,   14,  329,   67,  231,    1]),
#   tensor([  0,  26,  46,  69,  92, 118, 138, 162])),
#  (tensor([2, 1, 1, 0, 1, 0, 0, 0]),
#   tensor([ 134,  742,   41,    6,  213,   47,    3,  407,   15,  166, 1626,  165,
#              2,   15,  343,  238,    7,   47,    9,  111,   68,    4,  813,   11,
#              0,   53,   37, 2443,    7,  194,  148,  237,   87,    8,   96,  138,
#             32,   80,  332,   16,  451,   11,   15,  138,   43,    1,   18,   24,
#              5,   19,   37,   23,  541,    2, 1858,   29,   62, 1006,   68,  800,
#           2117,  621,   13,   44,  703,   11,    8,  238, 1080,   20,   10,   16,
#            484,  113,   11,  605, 1546,   91,   11,  159,   14,   11, 1641,    7,
#              8, 1752,  202,   71,  164,   38,    0,    2, 1680,   23,  240,    5,
#             19,   25,  205,   79,   37,  902,    0,   72, 1215,   37,  295,    2,
#            615, 1841,  100,    1,  731,  507,   17,    0,   23,  109,    2,  281,
#             66,  260,   58,    3,   24,    5,   19,  192,   39,   36,    1,    0,
#             97,    5,   19, 1136, 1480,   22,   52,    6,   53,  354,  117,    8,
#            634,  889,   66,  181,  117, 1101,    8, 2143, 1807,    1, 2070]),
#   tensor([  0,   4,  17,  29,  58,  84, 102, 132])),
#  (tensor([0, 2, 2, 0, 0, 0, 0, 1]),
#   tensor([   9,  122,  130,  801,   56,   46,    2,   22,   86,  155,   11,   30,
#            576,    1,  349,    5,   19,   37, 2578,    1,  344,    2, 4027,   10,
#             18,   79,   45,   37,   48,  300,    2,  156,   17,  402,    1,   22,
#             50,   79,   37,  860,  356,    1,    3,  182,  192,   29, 2254,  353,
#             10,   64,  143,   16,  158,  290,   10,   18,    5,   28,  356,    6,
#             24,    9,   76,  288,   21,   81,    7,    3,  182,    4,  401,    6,
#           2354,    0,   12,    2, 3475,   10,  574,    3,  169,   25,  131,  484,
#            978,   10,   43,  148,   31,    1,  519,  119,   20,   15,  532, 1134,
#             76,  457,   21,   11,  549,   55,   24,    5,   19,   33,  189,    2,
#            304,    1,  198,    0,  447,    1, 3294,   17,  432,    1, 3962, 2487,
#              1, 1698,    2,    0,    1,   31,   50,   10,   31,  490,   10,   31,
#            271,    1,   39,   36,    1,    0,    9,  148,   21,    9,  493,   15,
#             12,   14,  441,   17,    4,    0,  114,   14, 2540,  604,  260,   15,
#            238,    6, 1330,  454,   29,    9,   27,   11,    4, 1817,   91,  503,
#              3,    5,   59, 1152]),
#   tensor([  0,  20,  42,  72,  96, 110, 138, 162])),
#  (tensor([1, 0, 0, 2, 1, 0, 2, 0]),
#   tensor([   9,    5,  115,  197,    1,  167,   16,   57,    2,  361,    1,    1,
#              1,   43,    3,    5,   59,   48, 2001,   11,   15,  932,  139,    0,
#              3,   33,    2,   37,    0,  641,  764,  810,   17,    4, 1248,  527,
#              1,   73, 1213,    3,    5,   59, 2477,    1,   29, 2162,   14,  423,
#            214, 1052,   14,  287,  276,  163,   30,    4,   52,   66,  148,  162,
#            169,  321,   35, 2162,   79,   27, 1336, 1159,    6,  365,   60,    0,
#             13,  251,    1,   39,   36,    1,    0,   33,   21,   58,   20,   32,
#           2116,  133,    1,    1,    1,  141,   34,  135,    6,    0,  651,   10,
#            632,   21,    8,   71,  164,   38,  443, 1145,    2, 2335,   48,    3,
#             24,  109,   77,   20,  195,  353,  140,  129,   89,    4,  425, 1715,
#             56,   46,    3,    5,   93,  178, 1147,    6,   48,    0,    6,   32,
#             16,   27,   51,  956,  220,    6,   22,  227,   12,    2,  443, 2142,
#             16,   82,  170,    2,  133,    1,  203,   43, 1426,    1,    1,    1,
#              1,    0]),
#   tensor([  0,  13,  44,  67,  79,  94, 116, 131])),
#  ...]

# %% [markdown]
# train_loader is tokenized values we processed

# %% [markdown]
# Model building

# %%
# ====== Step 1 ========= 
class SpamClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim):
        super().__init__()
        self.embedding = nn.EmbeddingBag(vocab_size, embed_dim, mode='mean') # embedding layer
        self.Linear1 = nn.Linear(embed_dim, 1)
        self.Dropout = nn.Dropout(p=0.1)
    
    def forward(self, text, offsets):
        # note we need offsets to indicate which document we have
        out = self.embedding(text, offsets)
        out = self.Dropout(out)
        out = self.Linear1(out)
        return out
        # for the last layer, we don't apply activation because we can use BCEWithLogitsLoss to combine sigmoid with BCELoss
        
# model initalization
embed_dim = 8
model = SpamClassifier(len(vocabulary), embed_dim)

# %%
# ======= Step 2 ==========
loss_fn = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

# %%
def evaluate(dataloader):
    
    y_pred = torch.tensor([]) # store prediction
    y_true = torch.tensor([]) # store true label
    
    model.eval()
    with torch.no_grad():
        for label, text, offsets in dataloader:
            y_pred_batch = model(text, offsets)
            
            y_pred = torch.cat((y_pred, y_pred_batch.squeeze()))
            y_true = torch.cat((y_true, label.squeeze()))
            
    return y_pred, y_true

# %%
# ======== Step 3 ==============
epochs = 300
for epoch in range(epochs):
    
    for y_train, text, offsets in train_loader:
        # zero the parameter gradients
        optimizer.zero_grad()

        # calulate output and loss 
        y_pred_train = model(text, offsets)
        loss = loss_fn(y_pred_train.squeeze(), y_train.float())

        # backprop and take a step
        loss.backward()
        optimizer.step()
    
    # evaluate on validation set
    y_pred_val, y_val = evaluate(val_loader)
    loss_val = loss_fn(y_pred_val.squeeze(), y_val.float())
    
    # note when making prediction, do add sigmoid activation
    pred_label = (torch.sigmoid(y_pred_val) > 0.5).long() # find out the class prediction
    acc = (pred_label == y_val).float().sum()/y_val.shape[0]
    
    model.train() # because when evaluating we change mode to eval mode
    
    print('Epoch {}: {:.4f} (train), {:.4f} (val), {:.4f} (val acc)'.format(epoch, loss, loss_val, acc))
# Out:
# Epoch 0: 0.2899 (train), -0.4224 (val), 0.5694 (val acc)
# Epoch 1: 0.0001 (train), -3.0350 (val), 0.5775 (val acc)
# Epoch 2: 1.0023 (train), -7.1558 (val), 0.5727 (val acc)
# Epoch 3: -13.8849 (train), -12.6754 (val), 0.5624 (val acc)
# Epoch 4: 35.0652 (train), -19.2193 (val), 0.5631 (val acc)
# Epoch 5: 4.3165 (train), -27.0223 (val), 0.5591 (val acc)
# Epoch 6: 0.0004 (train), -35.8699 (val), 0.5569 (val acc)
# Epoch 7: -74.2605 (train), -45.8017 (val), 0.5540 (val acc)
# Epoch 8: -248.7891 (train), -56.6917 (val), 0.5543 (val acc)
# Epoch 9: -33.8463 (train), -68.8412 (val), 0.5569 (val acc)
# Epoch 10: -289.0657 (train), -82.3842 (val), 0.5547 (val acc)
# Epoch 11: -47.0130 (train), -96.3353 (val), 0.5573 (val acc)
# Epoch 12: 47.8339 (train), -111.3066 (val), 0.5547 (val acc)
# Epoch 13: -180.4846 (train), -127.4008 (val), 0.5551 (val acc)
# Epoch 14: -186.3135 (train), -144.5322 (val), 0.5558 (val acc)
# Epoch 15: -190.9116 (train), -163.0947 (val), 0.5569 (val acc)
# Epoch 16: 33.4859 (train), -182.3635 (val), 0.5576 (val acc)
# Epoch 17: 70.8089 (train), -202.1613 (val), 0.5580 (val acc)
# Epoch 18: 58.2079 (train), -223.3307 (val), 0.5547 (val acc)
# Epoch 19: -38.5119 (train), -245.1871 (val), 0.5569 (val acc)
# Epoch 20: -3014.2896 (train), -268.5162 (val), 0.5565 (val acc)
# Epoch 21: 909.0059 (train), -292.6488 (val), 0.5576 (val acc)
# Epoch 22: 0.7279 (train), -317.3070 (val), 0.5580 (val acc)
# Epoch 23: -1119.8953 (train), -343.2165 (val), 0.5565 (val acc)
# Epoch 24: -748.8519 (train), -370.8814 (val), 0.5558 (val acc)
# Epoch 25: 0.0000 (train), -398.9177 (val), 0.5576 (val acc)
# Epoch 26: 95.5209 (train), -428.3753 (val), 0.5514 (val acc)
# Epoch 27: 153.7226 (train), -458.0089 (val), 0.5547 (val acc)
# Epoch 28: 155.1718 (train), -489.4733 (val), 0.5576 (val acc)
# Epoch 29: 48.0503 (train), -521.6428 (val), 0.5492 (val acc)
# Epoch 30: -5163.2261 (train), -554.5451 (val), 0.5554 (val acc)
# Epoch 31: -1063.0265 (train), -588.3265 (val), 0.5558 (val acc)
# Epoch 32: 630.4408 (train), -623.7606 (val), 0.5554 (val acc)
# Epoch 33: 1418.6525 (train), -660.2954 (val), 0.5551 (val acc)
# Epoch 34: 0.0000 (train), -697.1331 (val), 0.5551 (val acc)
# Epoch 35: -4824.8032 (train), -734.6692 (val), 0.5551 (val acc)
# Epoch 36: -3203.8716 (train), -773.3112 (val), 0.5558 (val acc)
# Epoch 37: -777.7011 (train), -813.5680 (val), 0.5554 (val acc)
# Epoch 38: -1330.2833 (train), -854.3786 (val), 0.5540 (val acc)
# Epoch 39: -7931.8394 (train), -896.2227 (val), 0.5565 (val acc)
# Epoch 40: 560.1807 (train), -939.3495 (val), 0.5554 (val acc)
# Epoch 41: 209.3235 (train), -983.0443 (val), 0.5551 (val acc)
# Epoch 42: 483.9253 (train), -1028.2380 (val), 0.5554 (val acc)
# Epoch 43: 146.4771 (train), -1074.4976 (val), 0.5551 (val acc)
# Epoch 44: -3780.8093 (train), -1120.2479 (val), 0.5503 (val acc)
# Epoch 45: -762.2932 (train), -1168.7051 (val), 0.5536 (val acc)
# Epoch 46: 0.0000 (train), -1216.8729 (val), 0.5543 (val acc)
# Epoch 47: 15.7550 (train), -1266.3970 (val), 0.5540 (val acc)
# Epoch 48: 203.7159 (train), -1317.4874 (val), 0.5551 (val acc)
# Epoch 49: 0.0000 (train), -1370.2598 (val), 0.5551 (val acc)
# Epoch 50: -2985.7212 (train), -1423.6462 (val), 0.5540 (val acc)
# Epoch 51: 929.1484 (train), -1478.6130 (val), 0.5536 (val acc)
# Epoch 52: -2110.2300 (train), -1533.5148 (val), 0.5507 (val acc)
# Epoch 53: 5.1717 (train), -1590.3455 (val), 0.5543 (val acc)
# Epoch 54: 0.0000 (train), -1647.8922 (val), 0.5543 (val acc)
# Epoch 55: 1021.2559 (train), -1705.6233 (val), 0.5554 (val acc)
# Epoch 56: 637.3945 (train), -1764.6381 (val), 0.5543 (val acc)
# Epoch 57: 180.5076 (train), -1825.0175 (val), 0.5554 (val acc)
# Epoch 58: -1324.8429 (train), -1886.7146 (val), 0.5551 (val acc)
# Epoch 59: -1516.2610 (train), -1949.3906 (val), 0.5547 (val acc)
# Epoch 60: -21909.4629 (train), -2011.8480 (val), 0.5547 (val acc)
# Epoch 61: 940.6518 (train), -2075.9758 (val), 0.5547 (val acc)
# Epoch 62: -6704.4951 (train), -2138.1880 (val), 0.5503 (val acc)
# Epoch 63: -4656.0781 (train), -2203.6089 (val), 0.5558 (val acc)
# Epoch 64: 1050.0227 (train), -2270.8159 (val), 0.5547 (val acc)
# Epoch 65: -3405.1902 (train), -2338.7378 (val), 0.5562 (val acc)
# Epoch 66: -2761.0032 (train), -2409.2349 (val), 0.5543 (val acc)
# Epoch 67: -11914.9951 (train), -2479.7017 (val), 0.5558 (val acc)
# Epoch 68: -4315.4482 (train), -2551.0872 (val), 0.5543 (val acc)
# Epoch 69: 2529.0620 (train), -2621.6799 (val), 0.5543 (val acc)
# Epoch 70: 23.6714 (train), -2694.6143 (val), 0.5554 (val acc)
# Epoch 71: 641.6799 (train), -2767.5042 (val), 0.5551 (val acc)
# Epoch 72: -5329.0942 (train), -2841.4146 (val), 0.5543 (val acc)
# Epoch 73: 425.2396 (train), -2917.2913 (val), 0.5554 (val acc)
# Epoch 74: -17178.2734 (train), -2992.3862 (val), 0.5547 (val acc)
# Epoch 75: 4142.1245 (train), -3070.2607 (val), 0.5543 (val acc)
# Epoch 76: -9176.2588 (train), -3149.5891 (val), 0.5547 (val acc)
# Epoch 77: 0.0000 (train), -3230.2222 (val), 0.5554 (val acc)
# Epoch 78: -5856.3677 (train), -3312.5881 (val), 0.5551 (val acc)
# Epoch 79: 786.5366 (train), -3393.7407 (val), 0.5547 (val acc)
# Epoch 80: -10406.2227 (train), -3476.2808 (val), 0.5551 (val acc)
# Epoch 81: 0.0000 (train), -3559.7734 (val), 0.5547 (val acc)
# Epoch 82: 1023.0467 (train), -3643.7004 (val), 0.5547 (val acc)
# Epoch 83: -45276.5195 (train), -3728.9082 (val), 0.5551 (val acc)
# Epoch 84: -1562.8182 (train), -3816.2378 (val), 0.5547 (val acc)
# Epoch 85: 200.8332 (train), -3903.3237 (val), 0.5547 (val acc)
# Epoch 86: -1021.8240 (train), -3990.3533 (val), 0.5543 (val acc)
# Epoch 87: 8.0508 (train), -4077.4065 (val), 0.5540 (val acc)
# Epoch 88: -2768.1162 (train), -4167.4634 (val), 0.5510 (val acc)
# Epoch 89: 7409.9482 (train), -4258.8560 (val), 0.5547 (val acc)
# Epoch 90: 5804.5498 (train), -4350.5562 (val), 0.5540 (val acc)
# Epoch 91: -36449.9766 (train), -4442.0449 (val), 0.5547 (val acc)
# Epoch 92: -7696.0210 (train), -4536.1313 (val), 0.5547 (val acc)
# Epoch 93: -8821.0303 (train), -4630.8867 (val), 0.5554 (val acc)
# Epoch 94: 1397.8781 (train), -4726.4106 (val), 0.5547 (val acc)
# Epoch 95: 7.0662 (train), -4823.7847 (val), 0.5540 (val acc)
# Epoch 96: -7148.5020 (train), -4921.3735 (val), 0.5551 (val acc)
# Epoch 97: 0.0000 (train), -5020.2539 (val), 0.5547 (val acc)
# Epoch 98: 1092.3386 (train), -5118.6748 (val), 0.5547 (val acc)
# Epoch 99: 7606.4570 (train), -5220.1768 (val), 0.5540 (val acc)
# Epoch 100: -5467.4644 (train), -5322.2754 (val), 0.5536 (val acc)
# Epoch 101: 265.3379 (train), -5424.4902 (val), 0.5543 (val acc)
# Epoch 102: 190.0721 (train), -5528.9697 (val), 0.5547 (val acc)
# Epoch 103: 1708.1837 (train), -5632.9009 (val), 0.5547 (val acc)
# Epoch 104: -15771.2998 (train), -5737.9775 (val), 0.5547 (val acc)
# Epoch 105: 4465.2988 (train), -5844.4463 (val), 0.5551 (val acc)
# Epoch 106: -4088.1294 (train), -5953.6006 (val), 0.5543 (val acc)
# Epoch 107: -9918.8848 (train), -6061.2964 (val), 0.5551 (val acc)
# Epoch 108: 42.1880 (train), -6171.0396 (val), 0.5540 (val acc)
# Epoch 109: 4381.4810 (train), -6283.1475 (val), 0.5540 (val acc)
# Epoch 110: 147.2961 (train), -6395.7642 (val), 0.5503 (val acc)
# Epoch 111: 7.6831 (train), -6507.3569 (val), 0.5547 (val acc)
# Epoch 112: 5845.1650 (train), -6619.5317 (val), 0.5543 (val acc)
# Epoch 113: -16606.9746 (train), -6735.5083 (val), 0.5543 (val acc)
# Epoch 114: -23566.5781 (train), -6851.8423 (val), 0.5547 (val acc)
# Epoch 115: 1613.5249 (train), -6969.6382 (val), 0.5547 (val acc)
# Epoch 116: -24363.0293 (train), -7087.5029 (val), 0.5551 (val acc)
# Epoch 117: -10154.1240 (train), -7204.4199 (val), 0.5554 (val acc)
# Epoch 118: 0.0000 (train), -7322.8970 (val), 0.5551 (val acc)
# Epoch 119: 382.2171 (train), -7442.6777 (val), 0.5547 (val acc)
# Epoch 120: -9876.7842 (train), -7564.2744 (val), 0.5540 (val acc)
# Epoch 121: 2437.8596 (train), -7687.7520 (val), 0.5551 (val acc)
# Epoch 122: 32.8224 (train), -7810.9814 (val), 0.5551 (val acc)
# Epoch 123: 20723.2148 (train), -7937.3809 (val), 0.5543 (val acc)
# Epoch 124: -16756.0098 (train), -8065.9331 (val), 0.5547 (val acc)
# Epoch 125: -12020.2891 (train), -8191.7080 (val), 0.5547 (val acc)
# Epoch 126: -16579.8457 (train), -8316.2031 (val), 0.5551 (val acc)
# Epoch 127: 318.0935 (train), -8446.1816 (val), 0.5547 (val acc)
# Epoch 128: -78382.1875 (train), -8576.1660 (val), 0.5547 (val acc)
# Epoch 129: -12152.0117 (train), -8706.2031 (val), 0.5547 (val acc)
# Epoch 130: 12313.2529 (train), -8839.6230 (val), 0.5543 (val acc)
# Epoch 131: 515.8973 (train), -8969.8535 (val), 0.5543 (val acc)
# Epoch 132: -43406.7227 (train), -9105.2256 (val), 0.5540 (val acc)
# Epoch 133: -6883.5742 (train), -9238.3096 (val), 0.5554 (val acc)
# Epoch 134: 3001.7495 (train), -9375.2041 (val), 0.5554 (val acc)
# Epoch 135: 0.0000 (train), -9512.3770 (val), 0.5551 (val acc)
# Epoch 136: 0.0000 (train), -9650.8389 (val), 0.5551 (val acc)
# Epoch 137: 8246.8203 (train), -9789.7588 (val), 0.5551 (val acc)
# Epoch 138: 10106.3389 (train), -9931.1279 (val), 0.5554 (val acc)
# Epoch 139: 2638.1006 (train), -10074.0693 (val), 0.5554 (val acc)
# Epoch 140: 0.0000 (train), -10215.2275 (val), 0.5551 (val acc)
# Epoch 141: 4278.4502 (train), -10358.4551 (val), 0.5551 (val acc)
# Epoch 142: 14599.5410 (train), -10501.9443 (val), 0.5547 (val acc)
# Epoch 143: 0.0000 (train), -10647.5342 (val), 0.5551 (val acc)
# Epoch 144: -38171.0273 (train), -10791.0850 (val), 0.5547 (val acc)
# Epoch 145: 0.0000 (train), -10937.4561 (val), 0.5554 (val acc)
# Epoch 146: 1656.2351 (train), -11085.4814 (val), 0.5551 (val acc)
# Epoch 147: -35446.9102 (train), -11231.1523 (val), 0.5551 (val acc)
# Epoch 148: 8367.3037 (train), -11383.0410 (val), 0.5547 (val acc)
# Epoch 149: -227.3462 (train), -11530.8711 (val), 0.5551 (val acc)
# Epoch 150: -46950.7812 (train), -11683.2480 (val), 0.5547 (val acc)
# Epoch 151: -40996.2070 (train), -11833.0693 (val), 0.5551 (val acc)
# Epoch 152: -23031.0645 (train), -11985.3594 (val), 0.5547 (val acc)
# Epoch 153: -38765.3750 (train), -12138.5430 (val), 0.5551 (val acc)
# Epoch 154: 10060.4746 (train), -12293.8564 (val), 0.5551 (val acc)
# Epoch 155: -24740.0098 (train), -12447.0000 (val), 0.5551 (val acc)
# Epoch 156: -113378.3359 (train), -12602.6025 (val), 0.5543 (val acc)
# Epoch 157: -1931.0996 (train), -12761.0967 (val), 0.5554 (val acc)
# Epoch 158: 4353.4502 (train), -12917.4277 (val), 0.5554 (val acc)
# Epoch 159: 12565.8809 (train), -13074.8242 (val), 0.5551 (val acc)
# Epoch 160: 12298.0996 (train), -13233.7793 (val), 0.5551 (val acc)
# Epoch 161: 17657.2422 (train), -13398.3086 (val), 0.5547 (val acc)
# Epoch 162: -162865.1562 (train), -13559.5273 (val), 0.5558 (val acc)
# Epoch 163: 10723.6777 (train), -13724.1250 (val), 0.5551 (val acc)
# Epoch 164: -34689.2734 (train), -13891.4893 (val), 0.5503 (val acc)
# Epoch 165: -17525.8926 (train), -14058.3418 (val), 0.5554 (val acc)
# Epoch 166: 0.0000 (train), -14223.6963 (val), 0.5551 (val acc)
# Epoch 167: -32894.0781 (train), -14392.9014 (val), 0.5558 (val acc)
# Epoch 168: -27667.2070 (train), -14561.6592 (val), 0.5554 (val acc)
# Epoch 169: -22268.5352 (train), -14733.1953 (val), 0.5507 (val acc)
# Epoch 170: 2920.3054 (train), -14901.8809 (val), 0.5558 (val acc)
# Epoch 171: 5317.6401 (train), -15074.1016 (val), 0.5554 (val acc)
# Epoch 172: 1985.7850 (train), -15248.5918 (val), 0.5547 (val acc)
# Epoch 173: 0.0000 (train), -15421.0166 (val), 0.5551 (val acc)
# Epoch 174: 10373.5098 (train), -15599.2920 (val), 0.5496 (val acc)
# Epoch 175: 12479.9375 (train), -15773.7178 (val), 0.5554 (val acc)
# Epoch 176: -29298.4258 (train), -15948.2881 (val), 0.5554 (val acc)
# Epoch 177: -149426.8906 (train), -16125.0967 (val), 0.5554 (val acc)
# Epoch 178: 0.0000 (train), -16303.4785 (val), 0.5503 (val acc)
# Epoch 179: 0.0000 (train), -16480.5664 (val), 0.5551 (val acc)
# Epoch 180: 778.2404 (train), -16659.2891 (val), 0.5551 (val acc)
# Epoch 181: -63795.5859 (train), -16837.1855 (val), 0.5558 (val acc)
# Epoch 182: -113184.4141 (train), -17018.6270 (val), 0.5547 (val acc)
# Epoch 183: 23477.7969 (train), -17199.9902 (val), 0.5510 (val acc)
# Epoch 184: -35533.5859 (train), -17380.4492 (val), 0.5551 (val acc)
# Epoch 185: -38190.3945 (train), -17563.6777 (val), 0.5554 (val acc)
# Epoch 186: -32774.8008 (train), -17752.6680 (val), 0.5562 (val acc)
# Epoch 187: 109512.8984 (train), -17940.1504 (val), 0.5558 (val acc)
# Epoch 188: -47051.9297 (train), -18127.2617 (val), 0.5499 (val acc)
# Epoch 189: 0.0000 (train), -18316.5137 (val), 0.5551 (val acc)
# Epoch 190: 0.0000 (train), -18506.0117 (val), 0.5554 (val acc)
# Epoch 191: 6.2501 (train), -18697.4824 (val), 0.5551 (val acc)
# Epoch 192: -70673.3516 (train), -18885.3535 (val), 0.5554 (val acc)
# Epoch 193: 0.0000 (train), -19082.0312 (val), 0.5554 (val acc)
# Epoch 194: 0.0000 (train), -19278.9551 (val), 0.5558 (val acc)
# Epoch 195: -64.5607 (train), -19467.3984 (val), 0.5554 (val acc)
# Epoch 196: 13.2181 (train), -19665.6777 (val), 0.5543 (val acc)
# Epoch 197: 61.9666 (train), -19866.4883 (val), 0.5547 (val acc)
# Epoch 198: 2393.9912 (train), -20065.3574 (val), 0.5554 (val acc)
# Epoch 199: 0.0000 (train), -20263.6738 (val), 0.5551 (val acc)
# Epoch 200: 8008.6953 (train), -20461.1914 (val), 0.5558 (val acc)
# Epoch 201: 0.0000 (train), -20661.2676 (val), 0.5554 (val acc)
# Epoch 202: -100926.4375 (train), -20867.8906 (val), 0.5551 (val acc)
# Epoch 203: 0.0000 (train), -21071.6738 (val), 0.5547 (val acc)
# Epoch 204: 19102.4023 (train), -21276.0059 (val), 0.5558 (val acc)
# Epoch 205: 3100.4463 (train), -21480.8203 (val), 0.5551 (val acc)
# Epoch 206: -43942.5586 (train), -21683.2812 (val), 0.5547 (val acc)
# Epoch 207: 37976.6445 (train), -21890.9512 (val), 0.5551 (val acc)
# Epoch 208: 0.0000 (train), -22098.7207 (val), 0.5558 (val acc)
# Epoch 209: -264981.2500 (train), -22306.3770 (val), 0.5554 (val acc)
# Epoch 210: -93051.3281 (train), -22516.9980 (val), 0.5554 (val acc)
# Epoch 211: 3812.5215 (train), -22725.7051 (val), 0.5554 (val acc)
# Epoch 212: 8900.7773 (train), -22936.7402 (val), 0.5551 (val acc)
# Epoch 213: 69019.3984 (train), -23152.1777 (val), 0.5547 (val acc)
# Epoch 214: 21544.9082 (train), -23363.7754 (val), 0.5551 (val acc)
# Epoch 215: 0.0000 (train), -23576.4414 (val), 0.5551 (val acc)
# Epoch 216: -89435.5938 (train), -23790.2148 (val), 0.5547 (val acc)
# Epoch 217: 0.0000 (train), -24006.9727 (val), 0.5554 (val acc)
# Epoch 218: 6.2964 (train), -24226.6934 (val), 0.5547 (val acc)
# Epoch 219: 0.0000 (train), -24448.9785 (val), 0.5551 (val acc)
# Epoch 220: 0.0000 (train), -24670.7715 (val), 0.5543 (val acc)
# Epoch 221: 3668.4192 (train), -24889.1484 (val), 0.5551 (val acc)
# Epoch 222: 3827.7556 (train), -25106.9434 (val), 0.5554 (val acc)
# Epoch 223: -71033.0391 (train), -25330.6992 (val), 0.5510 (val acc)
# Epoch 224: -303747.2188 (train), -25553.1445 (val), 0.5554 (val acc)
# Epoch 225: 11182.7656 (train), -25781.6719 (val), 0.5551 (val acc)
# Epoch 226: -215000.4844 (train), -26006.6367 (val), 0.5551 (val acc)
# Epoch 227: 0.0000 (train), -26235.7773 (val), 0.5547 (val acc)
# Epoch 228: 0.0000 (train), -26462.1680 (val), 0.5554 (val acc)
# Epoch 229: 0.0000 (train), -26683.0801 (val), 0.5547 (val acc)
# Epoch 230: -21148.1504 (train), -26910.8906 (val), 0.5551 (val acc)
# Epoch 231: 1397.7506 (train), -27142.9316 (val), 0.5547 (val acc)
# Epoch 232: 7223.9326 (train), -27372.7637 (val), 0.5503 (val acc)
# Epoch 233: 39640.2734 (train), -27604.2051 (val), 0.5554 (val acc)
# Epoch 234: 11861.4062 (train), -27836.4316 (val), 0.5551 (val acc)
# Epoch 235: 0.0000 (train), -28069.6719 (val), 0.5551 (val acc)
# Epoch 236: -53009.5000 (train), -28308.5957 (val), 0.5551 (val acc)
# Epoch 237: 0.0000 (train), -28547.1621 (val), 0.5554 (val acc)
# Epoch 238: -93912.0000 (train), -28779.7246 (val), 0.5551 (val acc)
# Epoch 239: -142800.7500 (train), -29014.0508 (val), 0.5551 (val acc)
# Epoch 240: 3.6312 (train), -29262.6719 (val), 0.5551 (val acc)
# Epoch 241: -56156.3398 (train), -29500.2910 (val), 0.5554 (val acc)
# Epoch 242: -163835.3125 (train), -29740.1523 (val), 0.5551 (val acc)
# Epoch 243: 18200.3457 (train), -29985.3340 (val), 0.5551 (val acc)
# Epoch 244: -262808.8125 (train), -30225.1504 (val), 0.5558 (val acc)
# Epoch 245: 18.0751 (train), -30472.5723 (val), 0.5554 (val acc)
# Epoch 246: -284092.0312 (train), -30722.0117 (val), 0.5558 (val acc)
# Epoch 247: 73667.7344 (train), -30964.9629 (val), 0.5558 (val acc)
# Epoch 248: 832.4484 (train), -31212.6484 (val), 0.5510 (val acc)
# Epoch 249: -237320.8750 (train), -31460.2871 (val), 0.5554 (val acc)
# Epoch 250: 0.7909 (train), -31712.3262 (val), 0.5551 (val acc)
# Epoch 251: -67367.2188 (train), -31960.9141 (val), 0.5551 (val acc)
# Epoch 252: 19649.2695 (train), -32212.1152 (val), 0.5554 (val acc)
# Epoch 253: -30322.1016 (train), -32465.3750 (val), 0.5554 (val acc)
# Epoch 254: -59399.8125 (train), -32718.4609 (val), 0.5554 (val acc)
# Epoch 255: 10642.1279 (train), -32971.2695 (val), 0.5551 (val acc)
# Epoch 256: 2592.9155 (train), -33229.2852 (val), 0.5554 (val acc)
# Epoch 257: 9849.5508 (train), -33486.2148 (val), 0.5551 (val acc)
# Epoch 258: 4577.8101 (train), -33743.9180 (val), 0.5554 (val acc)
# Epoch 259: 0.0000 (train), -34005.9531 (val), 0.5554 (val acc)
# Epoch 260: 9734.0713 (train), -34265.6094 (val), 0.5551 (val acc)
# Epoch 261: -15242.0547 (train), -34524.8203 (val), 0.5554 (val acc)
# Epoch 262: 36004.7188 (train), -34778.4922 (val), 0.5554 (val acc)
# Epoch 263: 14353.2344 (train), -35038.9883 (val), 0.5551 (val acc)
# Epoch 264: 120707.8750 (train), -35295.8594 (val), 0.5507 (val acc)
# Epoch 265: 0.0000 (train), -35553.2344 (val), 0.5551 (val acc)
# Epoch 266: -144646.5625 (train), -35819.4180 (val), 0.5554 (val acc)
# Epoch 267: 11518.5684 (train), -36089.2344 (val), 0.5554 (val acc)
# Epoch 268: -53994.8477 (train), -36357.1875 (val), 0.5554 (val acc)
# Epoch 269: 17421.6367 (train), -36625.1875 (val), 0.5554 (val acc)
# Epoch 270: -76486.5625 (train), -36896.8359 (val), 0.5547 (val acc)
# Epoch 271: 0.0000 (train), -37168.2422 (val), 0.5554 (val acc)
# Epoch 272: 2060.6223 (train), -37433.5664 (val), 0.5551 (val acc)
# Epoch 273: 0.0000 (train), -37705.2031 (val), 0.5554 (val acc)
# Epoch 274: -70942.1875 (train), -37983.1523 (val), 0.5554 (val acc)
# Epoch 275: 24165.7734 (train), -38255.6523 (val), 0.5510 (val acc)
# Epoch 276: 23061.3164 (train), -38526.3945 (val), 0.5554 (val acc)
# Epoch 277: 0.0052 (train), -38803.5000 (val), 0.5551 (val acc)
# Epoch 278: -67997.4531 (train), -39081.4219 (val), 0.5554 (val acc)
# Epoch 279: -99941.5703 (train), -39358.5430 (val), 0.5551 (val acc)
# Epoch 280: 16863.7539 (train), -39637.7227 (val), 0.5554 (val acc)
# Epoch 281: 31.4485 (train), -39919.3164 (val), 0.5551 (val acc)
# Epoch 282: 76668.3750 (train), -40197.7266 (val), 0.5554 (val acc)
# Epoch 283: -120310.3281 (train), -40478.8906 (val), 0.5554 (val acc)
# Epoch 284: 16151.1660 (train), -40768.8047 (val), 0.5554 (val acc)
# Epoch 285: -25676.3379 (train), -41048.5625 (val), 0.5507 (val acc)
# Epoch 286: -63164.6484 (train), -41330.3359 (val), 0.5554 (val acc)
# Epoch 287: 0.0000 (train), -41614.5430 (val), 0.5551 (val acc)
# Epoch 288: -6962.8955 (train), -41901.9102 (val), 0.5551 (val acc)
# Epoch 289: 0.0000 (train), -42189.1055 (val), 0.5507 (val acc)
# Epoch 290: 10665.4600 (train), -42476.0938 (val), 0.5554 (val acc)
# Epoch 291: 40.5798 (train), -42770.6211 (val), 0.5551 (val acc)
# Epoch 292: -64323.9062 (train), -43060.4805 (val), 0.5547 (val acc)
# Epoch 293: 15550.7520 (train), -43348.3086 (val), 0.5554 (val acc)
# Epoch 294: -38549.6758 (train), -43636.9062 (val), 0.5551 (val acc)
# Epoch 295: -479367.7500 (train), -43926.7383 (val), 0.5547 (val acc)
# Epoch 296: 3264.9707 (train), -44223.7695 (val), 0.5551 (val acc)
# Epoch 297: 11206.4004 (train), -44519.2383 (val), 0.5551 (val acc)
# Epoch 298: 15842.8945 (train), -44812.4219 (val), 0.5551 (val acc)
# Epoch 299: 19476.9609 (train), -45109.5078 (val), 0.5554 (val acc)

# %%
# prediction on test data
y_pred_test, y_true_test = evaluate(test_loader)
y_pred_test = torch.sigmoid(y_pred_test) > 0.5

print(confusion_matrix(y_true_test, y_pred_test))
print(classification_report(y_true_test, y_pred_test))
# Out:
# [[1107  599    0]
#  [ 167  397    0]
#  [  19  435    0]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.65      0.74      1706
#          1.0       0.28      0.70      0.40       564
#          2.0       0.00      0.00      0.00       454
#
#     accuracy                           0.55      2724
#    macro avg       0.38      0.45      0.38      2724
# weighted avg       0.59      0.55      0.54      2724

# %% [markdown]
# using word embedding

# %%
# ===== Build vocabulary =====
vocab2 = build_vocab_from_iterator(
    [tokenizer(s) for s in train],
    specials=["<unk>"]
)

vocab2.set_default_index(vocab2["<unk>"])

# %%
# Function to convert a sentence to BoW sequence
vocab2_len = len(vocab2)
def index2onehot(idx, n = vocab2_len):
    eye = torch.eye(vocab2_len)
    return eye[:,idx]

def stobow(s):
    token_idxs = vocab2(tokenizer(s))
    return index2onehot(token_idxs), torch.Tensor(token_idxs).long()

# Convert all training sentences
bow_sequences = []
for s in train['review_text']:
    bow_sequences.append(stobow(s))

# %%
# Model class
class RNN(nn.Module):
    def __init__(self, n_features, n_class, hidden_dim=20):
        super().__init__()
        # Model layers
        self.rnn = nn.RNN(n_features, hidden_dim)
        self.fc = nn.Linear(hidden_dim, n_class)
        
    def forward(self, x):
        rnn_o, h = self.rnn(x)
        fc_o = self.fc(rnn_o[-1, :]) 
        return fc_o

# init model
model = RNN(n_features=vocab2_len, n_class=vocab2_len)

# init loss
loss_function = nn.CrossEntropyLoss()

# init optimizer
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)

# %%
max_iter = 300
seq_length = 2
loss_history = []
for epoch in range(max_iter):
    
    for i in range(len(bow_sequences)):
    
        Sent, tokens = bow_sequences[i]
        
        for j in range(Sent.shape[1]-seq_length):
            # loop over the two-grams
            X = Sent[:, j:j+seq_length] # j, j+1 words
            y = tokens[j+seq_length] # j+2 word as label
        
            optimizer.zero_grad()

            output = model(X.T) # pytorch requires input to be [Length, inputsize]
                        
            loss = loss_function(output, y)

            loss.backward()
            optimizer.step()

    # Collect loss at end of each iteration
    loss_history.append(loss.item())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23452\821130632.py in <module>
#      13             y = tokens[j+seq_length] # j+2 word as label
#      14
# ---> 15             optimizer.zero_grad()
#      16
#      17             output = model(X.T) # pytorch requires input to be [Length, inputsize]
#
# E:\Annaconda\lib\site-packages\torch\_compile.py in inner(*args, **kwargs)
#      22             import torch._dynamo
#      23
# ---> 24             return torch._dynamo.disable(fn, recursive)(*args, **kwargs)
#      25
#      26         return inner
#
# E:\Annaconda\lib\site-packages\torch\_dynamo\eval_frame.py in _fn(*args, **kwargs)
#     326             dynamic_ctx.__enter__()
#     327             try:
# --> 328                 return fn(*args, **kwargs)
#     329             finally:
#     330                 set_eval_frame(prior)
#
# E:\Annaconda\lib\site-packages\torch\optim\optimizer.py in zero_grad(self, set_to_none)
#     821                 for per_dtype_grads in per_device_and_dtype_grads.values():
#     822                     for grads in per_dtype_grads.values():
# --> 823                         torch._foreach_zero_(grads)
#     824
#     825     @overload
#
# E:\Annaconda\lib\site-packages\torch\autograd\profiler.py in __exit__(self, exc_type, exc_value, traceback)
#     646         if not torch.jit.is_scripting():
#     647             with torch._C.DisableTorchFunctionSubclass():
# --> 648                 torch.ops.profiler._record_function_exit._RecordFunction(record)
#     649         else:
#     650             torch.ops.profiler._record_function_exit(record)
#
# E:\Annaconda\lib\site-packages\torch\_ops.py in __call__(self, *args, **kwargs)
#     446
#     447     def __call__(self, *args, **kwargs):
# --> 448         return self._op(*args, **kwargs or {})
#     449
#     450     def __hash__(self):
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(loss_history)

# %% [markdown]
# Spam Classification

# %%
# preprocessing data
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder() 
target = le.fit_transform(train['airline_sentiment']) # convert target into integers
train['airline_sentiment'] = target
print(le.classes_) # this shows which index maps to which class

train.head()
# Out:
# [0 1 2]
#                review_id      user_name  airline_sentiment  \
# 930   569972097453137920  cristobalwong                  1
# 5873  568092537786748928  VegasRenegade                  1
# 5963  568028183267639297      CourtSnod                  2
# 7436  568993773277069312  KoolieAshSays                  1
# 2254  569227372223811584   zachkpearson                  2
#
#       sentiment_confidence negative_reason  negative_reason_confidence  \
# 930                 0.3350             NaN                         0.0
# 5873                0.3353             NaN                         0.0
# 5963                0.3356             NaN                         0.0
# 7436                0.3363             NaN                         0.0
# 2254                0.3366             NaN                         0.0
#
#             airline_name                                        review_text  \
# 930             Emirates  Thank you, ^JH, appreciate the prompt response...
# 5873           Lufthansa                    All Flights lead to VEGAS BABY!
# 5963           Lufthansa                             de-icing is important!
# 7436  Singapore Airlines                           oh. Makes sense. My bad.
# 2254            Emirates       . Thanks. Hopefully this is easily resolved.
#
#       thumbup_count         review_coordinates review_timestamp  \
# 930               0                        NaN  23/2/2015 13:28
# 5873              1                        NaN   18/2/2015 8:59
# 5963              0                        NaN   18/2/2015 4:44
# 7436              0  [40.88529232, -73.856635]  20/2/2015 20:41
# 2254              0                        NaN  21/2/2015 12:09
#
#                      review_city               user_timezone review  \
# 930       San Francisco Bay Area                        None      1
# 5873        The Wild Blue Yonder      Atlantic Time (Canada)      1
# 5963          Tennessee Original  Central Time (US & Canada)      2
# 7436  ÜT: 17.9889591,-76.7712636  Pacific Time (US & Canada)      1
# 2254            Portland, Oregon  Pacific Time (US & Canada)      2
#
#       user_name_count
# 930                 7
# 5873                1
# 5963                1
# 7436                1
# 2254                1

# %% [markdown]
# simplified adaboost (week 11)

# %%
shape=[len(train_review_text),find_max_list(train_review_text)]

# %%
shape
# Out:
# [8172, 39]

# %% [markdown]
# for each row number in train_review_text add zero values to match the shape of desired shape.

# %%
train_sentiment= list(train_data['airline_sentiment'])
train_review_text= []
for idx in range(len(train_data['review_text'])):
    train_token=doc_tokenizer2( list(train_data['review_text'])[idx])
    train_review_text.append(train_token)
y_train=np.array(train_sentiment)

val_sentiment= list(val_data['airline_sentiment'])
val_review_text= []
for idx in range(len(val_data['review_text'])):
    val_token=doc_tokenizer2( list(val_data['review_text'])[idx])
    val_review_text.append(val_token)
y_val=np.array(val_sentiment)

test_sentiment= list(test_data['airline_sentiment'])
test_review_text= []
for idx in range(len(test_data['review_text'])):
    test_token=doc_tokenizer2( list(test_data['review_text'])[idx])
    test_review_text.append(test_token)
y_test=np.array(test_sentiment)

# %%
find_max_list(train_review_text)
# Out:
# 39

# %%
find_max_list(test_review_text)
# Out:
# 40

# %%
def find_max_list(list):
    list_len = [len(i) for i in list]
    return(max(list_len))

def zeropad(data):
    max_length = 40
    train_review_text_pad = [sublist + [0] * (max_length - len(sublist)) for sublist in data]
    zero_pad=np.array(train_review_text_pad)
    return zero_pad

# %%
X_train=zeropad(train_review_text)
X_val=zeropad(val_review_text)
X_test=zeropad(test_review_text)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

weak_learner = DecisionTreeClassifier(max_leaf_nodes=8)#this is a hyper parameter and needs to be tunned
n_estimators = 300

adaboost_clf = AdaBoostClassifier(
    base_estimator=weak_learner,#Use estimator instead of base_estimator for sklearn over version 1.2 
    n_estimators=n_estimators,
    algorithm="SAMME",
    random_state=42,
).fit(X_train, y_train)
#where X_train is the number valued review text, and the y_train is the sentiment(0,1,2)

# %% [markdown]
# gradient boosting

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

dummy_clf = DummyClassifier()


def misclassification_error(y_true, y_pred):
    return 1 - accuracy_score(y_true, y_pred)


weak_learners_misclassification_error = misclassification_error(
    y_test, weak_learner.fit(X_train, y_train).predict(X_test)
)

dummy_classifiers_misclassification_error = misclassification_error(
    y_test, dummy_clf.fit(X_train, y_train).predict(X_test)
)

print(
    "DecisionTreeClassifier's misclassification_error: "
    f"{weak_learners_misclassification_error:.3f}"
)
print(
    "DummyClassifier's misclassification_error: "
    f"{dummy_classifiers_misclassification_error:.3f}"
)
# Out:
# DecisionTreeClassifier's misclassification_error: 0.350
# DummyClassifier's misclassification_error: 0.374

# %%
boosting_errors = pd.DataFrame(
    {
        "Number of trees": range(1, n_estimators + 1),
        "AdaBoost": [
            misclassification_error(y_test, y_pred)
            for y_pred in adaboost_clf.staged_predict(X_test)
        ],
    }
).set_index("Number of trees")
ax = boosting_errors.plot()
ax.set_ylabel("Misclassification error on test set")
ax.set_title("Convergence of AdaBoost algorithm")

plt.plot(
    [boosting_errors.index.min(), boosting_errors.index.max()],
    [weak_learners_misclassification_error, weak_learners_misclassification_error],
    color="tab:orange",
    linestyle="dashed",
)
plt.plot(
    [boosting_errors.index.min(), boosting_errors.index.max()],
    [
        dummy_classifiers_misclassification_error,
        dummy_classifiers_misclassification_error,
    ],
    color="c",
    linestyle="dotted",
)
plt.legend(["AdaBoost", "DecisionTreeClassifier", "DummyClassifier"], loc=1)
plt.show()

# %%
weak_learners_info = pd.DataFrame(
    {
        "Number of trees": range(1, n_estimators + 1),
        "Errors": adaboost_clf.estimator_errors_,
        "Weights": adaboost_clf.estimator_weights_,
    }
).set_index("Number of trees")

axs = weak_learners_info.plot(
    subplots=True, layout=(1, 2), figsize=(10, 4), legend=False, color="tab:blue"
)
axs[0, 0].set_ylabel("Train error")
axs[0, 0].set_title("Weak learner's training error")
axs[0, 1].set_ylabel("Weight")
axs[0, 1].set_title("Weak learner's weight")
fig = axs[0, 0].get_figure()
fig.suptitle("Weak learner's errors and weights for the AdaBoostClassifier")
fig.tight_layout()
